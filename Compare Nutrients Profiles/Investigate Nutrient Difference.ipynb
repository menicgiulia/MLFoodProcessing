# %%
import xport
import numpy as np
import pandas as pd
import os
import json
import pyperclip
import json
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import time
import textwrap


from os.path import isfile, join
# import networkx as nx

#https://songhuiming.github.io/pages/2017/04/02/jupyter-and-pandas-display/
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_colwidth', 0)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %%
def describe(df):
    return pd.concat([df.describe().T,
                      df.sum().rename('sum'),
                      df.mad().rename('mad'),
                      df.skew().rename('skew'),
                      df.kurt().rename('kurt'),
                     ], axis=1).T

# %%
def concat_columns(data_df, columns_keep, columns_concat, column_rename, column_concat):
    
    concat_df = pd.DataFrame(columns= columns_keep + [column_rename])
    
    concat_df_list = []
    
    for col in columns_concat:
        df = data_df[columns_keep + [col]].rename(columns={col: column_rename})
        df[column_concat] = col
        concat_df_list.append(df)
    
    return pd.concat(concat_df_list).reset_index(drop=True)

# %%
SMALL_SIZE = 14
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

matplotlib.rcParams['font.serif'] = "Times New Roman"
matplotlib.rcParams['font.family'] = "serif"
sns.set_style({'font.family':'serif', 'font.serif':'Times New Roman'})

# %%
import random

def get_random_color(pastel_factor = 0.5):
    return [(x+pastel_factor)/(1.0+pastel_factor) for x in [random.uniform(0,1.0) for i in [1,2,3]]]

def color_distance(c1,c2):
    return sum([abs(x[0]-x[1]) for x in zip(c1,c2)])

def generate_new_color(existing_colors,pastel_factor = 0.5):
    max_distance = None
    best_color = None
    for i in range(0,100):
        color = get_random_color(pastel_factor = pastel_factor)
        if not existing_colors:
            return color
        best_distance = min([color_distance(color,c) for c in existing_colors])
        if not max_distance or best_distance > max_distance:
            max_distance = best_distance
            best_color = color
    return best_color

def gen_rand_colors(n):
    colors = []

    for i in range(0, n):
        colors.append(generate_new_color(colors))
        
    return colors

# %% [markdown]
# # Important Functional Notes

# %% [markdown]
# # Load Data

# %%
# 57341000    'Cereal (Post Shredded Wheat''n Bran)'

# %%
excel_mess={
    'mess': [
        '4:00','6:00','8:00','10:00','12:00','14:00','16:00','18:00','18:01','18:02','18:03','20:04','16:01','18:04','20:01','22:01'
    ],
    'correct': [
        '4:0', '6:0', '8:0', '10:0', '12:0', '14:0', '16:0', '18:0', '18:1', '18:2', '18:3', '20:4', '16:1', '18:4', '20:1', '22:1'
    ]
}

excel_mess_dict = {excel_mess['mess'][i]: excel_mess['correct'][i] for i in range(len(excel_mess['mess']))} 

excel_mess_dict
# Out:
# {'4:00': '4:0',
#  '6:00': '6:0',
#  '8:00': '8:0',
#  '10:00': '10:0',
#  '12:00': '12:0',
#  '14:00': '14:0',
#  '16:00': '16:0',
#  '18:00': '18:0',
#  '18:01': '18:1',
#  '18:02': '18:2',
#  '18:03': '18:3',
#  '20:04': '20:4',
#  '16:01': '16:1',
#  '18:04': '18:4',
#  '20:01': '20:1',
#  '22:01': '22:1'}

# %%
def load_data_main():
    global fndds_cons_df
    
    fndds_cons_df = pd.read_csv('FNDDS_2015_Weighted_Consumption_WWEIA_nuts.csv', index_col=0)

    # fndds_FPro_df = pd.read_csv('FNDDS_2015_classified_with_58_nuts.csv')
    # fndds_FPro_df[['Food code', 'FPS', 'ens_FPS', 'ens_min_FPS']],

    fndds_FPro_df = pd.read_csv('FNDDS201520165foldsSMOTE_62Panel.csv')

    fndds_cons_df = pd.merge(
        fndds_FPro_df[['Food code', 'FPS', 'min_FPS', 'std_FPS']],
        fndds_cons_df,
        on='Food code', how='left')

    del fndds_FPro_df

    pass

load_data_main()
len(fndds_cons_df)
# Out:
# C:\anaconda3\envs\foodome\lib\site-packages\IPython\core\interactiveshell.py:3357: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# 8690

# %%
# THIS MUST ALWAYS BE FALSE...
'4:00' in fndds_cons_df.columns
# Out:
# False

# %% [markdown]
# # Filter Data

# %%
cols_messed_name = {
    '4:00': '4:0',
    '6:00': '6:0',
    '8:00': '8:0',
    '10:00': '10:0',
    '12:00': '12:0',
    '14:00': '14:0',
    '16:00': '16:0',
    '16:01': '16:1',
    '18:00': '18:0',
    '18:01': '18:1',
    '18:02': '18:2',
    '18:03': '18:3',
    '18:04': '18:4',
    '20:01': '20:1',
    '20:04': '20:4',
    '22:01': '22:1'
}

# %%
'''
WHEAT BRAN... it is from 2011
'''

ONLY_KEEP_TARGETED_YEAR = False

TARGETED_YEAR = ['2009', '2011'][1]

if ONLY_KEEP_TARGETED_YEAR is True:
    nut_panel = '99'
    path_foods_fndds_targetted = f'RFFNDDScleanedwithsalt_additionallab_PREDICTION99_5folds_SMOTE.csv'
else:
    path_foods_fndds_targetted = f'FNDDS_{TARGETED_YEAR}_classified_with_62_nuts.csv'
    nut_panel = '62 but Not Needed!'

foods_fndds_targetted_df = (
    pd.read_csv(path_foods_fndds_targetted)
    .rename(columns={'ens_FPS': 'FPS', 'ens_std_FPS': 'std_FPS', 'ens_min_FPS': 'min_FPS', 'Food_code': 'Food code',
                    'Main_food_description': 'Main food description'})
    .rename(columns=cols_messed_name)
    .drop(columns=['Unnamed: 0'])
)
foods_fndds_targetted_df.head()

# foods_fndds_targetted_df = foods_fndds_targetted_df[foods_fndds_2011_df['Food code'].isin([
#     57601100, # Wheat bran, unprocessed
#     57604100, # Whole wheat, cracked
# ])]

print(path_foods_fndds_targetted)

len(foods_fndds_targetted_df)
# Out:
# FNDDS_2011_classified_with_62_nuts.csv
# 7618

# %%
data_source_name = ''

if ONLY_KEEP_TARGETED_YEAR is True:
    fndds_cons_df = foods_fndds_targetted_df    
    data_source_name = 'FNDDS' + TARGETED_YEAR + 'P' + nut_panel
else:
    load_data_main()

    fndds_cons_df = (
        pd.concat([fndds_cons_df, foods_fndds_targetted_df])
        .drop_duplicates('Food code', keep='first')
        .reset_index(drop=True)
    #     .value_counts('Food code')
    )
    
    data_source_name = 'FNDDS2015+' + TARGETED_YEAR
    pass

print('ONLY_KEEP_TARGETED_YEAR:', ONLY_KEEP_TARGETED_YEAR)
print('data_source_name:', data_source_name)
len(fndds_cons_df)
# Out:
# ONLY_KEEP_TARGETED_YEAR: False
# data_source_name: FNDDS2015+2011
# 9616

# %%
# load_data_main()
set(fndds_cons_df.columns) - set(foods_fndds_targetted_df.columns)

# set(foods_fndds_targetted_df.columns) - set(fndds_cons_df.columns)
# list(foods_fndds_targetted_df.columns)
# Out:
# {'Calories',
#  'FPS',
#  'Grams',
#  'WWEIA Category description',
#  'WWEIA Category number',
#  'cat_digit_1',
#  'cat_digit_2',
#  'cat_digit_3',
#  'cat_digit_4',
#  'cat_digit_5',
#  'min_FPS',
#  'n',
#  'se.Calories',
#  'se.Grams',
#  'se.n',
#  'std_FPS',
#  'year_WWEIA_category'}

# %% [raw]
# foods_df = (
#     fndds_cons_df
#     .sort_values('FPS', ascending=False)
# )
#
# foods_df = foods_df[foods_df['Food code'].isin([
#     63101000, # apple, NFS
# ])]
#
#
# path_core_data = 'D:/Dropbox (CCNR)/Foodome Team Folder/Menichetti, Giulia/FoodProcessing/Datasets/FoodProX Core Data/'
# NHS_df = pd.read_csv(path_core_data + 'NHS_FoodProX_FNDDS_cols_53P.csv')
#
# # foods_df
# NHS_df = NHS_df.rename(columns={
#     'Label': 'Main food description',
#     'Var_name_prog': 'Food code'
# })
#
# NHS_df.head()
#
# len(
#     NHS_df.loc[:, 'Protein': 'Fatty acids, total polyunsaturated'].columns
# )
#
# cols_NHS = list(NHS_df.loc[:, 'Protein': 'Fatty acids, total polyunsaturated'].columns)
#
# # foods_df
# # NHS_df[NHS_df['Main food description'].str.contains('apple', case=False)]
#
# NHS_filt_df = NHS_df[NHS_df['Main food description'].str.contains('Fresh Apples, Pears', case=False)]
# foods_df = pd.concat([foods_df, NHS_filt_df])
#
# foods_df = foods_df[['Food code', 'Main food description', 'FPS', 'std_FPS', 'min_FPS'] + cols_NHS]
#
# # col_nuts = list(foods_df.loc[:, 'Protein':'Fatty acids, total polyunsaturated'].columns)
#
# mask = foods_df['Food code'] == 63101000
# foods_df.loc[mask, 'Main food description'] = '(FNDDS) ' + foods_df.loc[mask, 'Main food description']
#
# mask = foods_df['Food code'] == 'appl02d'
# foods_df.loc[mask, 'Main food description'] = '(NHS) ' + foods_df.loc[mask, 'Main food description']
#
# foods_df.to_csv('apple_NHS_FNDDS_nuts_compare_53.csv')
#
# foods_df

# %% [raw]
# foods_df = (
#     fndds_cons_df
#     .sort_values('FPS', ascending=False)
# )
# foods_df = foods_df[foods_df['Food code'].isin([
#     61210620, # Orange, sections, canned, juice pack
#     61119020  # Orange juice, 100%, frozen, reconstituted
# ])]
# foods_df

# %%
case_studies = [
    {
        'name': 'POST four cereals',
        'type': 'general',
        'food codes':[
            57237300, # Cereal (Post Honey Bunches of Oats with Almonds)
            57230000, # Cereal (Post Grape-Nuts)

            57417000, # Cereal (Post Shredded Wheat)
            57341000, # Cereal (Post Shredded Wheat'n Bran)
        ],
        'comparison base': 57341000, # Cereal (Post Shredded Wheat'n Bran)
    },
    {
        'name': 'POST WheatBran vs ShreddedWheat',
        'type': 'general',
        'food codes':[
            57417000, # Cereal (Post Shredded Wheat)
            57341000, # Cereal (Post Shredded Wheat'n Bran)
        ]
    },
    {
        'name': 'POST four cereals AND UnprocessedWheatBran',
        'type': 'general',
        'food codes':[
            57237300, #Cereal (Post Honey Bunches of Oats with Almonds)
            57230000, # Cereal (Post Grape-Nuts)

            57417000, # Cereal (Post Shredded Wheat)
            57341000, # Cereal (Post Shredded Wheat'n Bran)
            57601100, # Wheat bran, unprocessed
        ]
    },
    {
        'name': 'compare POST four cereals vs UnprocessedWheatBran',
        'type': 'general',
        'food codes':[
            57237300, #Cereal (Post Honey Bunches of Oats with Almonds)
            57230000, # Cereal (Post Grape-Nuts)

            57417000, # Cereal (Post Shredded Wheat)
            57341000, # Cereal (Post Shredded Wheat'n Bran)
            
            57601100, # Wheat bran, unprocessed
        ],
        'comparison base': 57601100, # Wheat bran, unprocessed
    },
    {
        'name': 'POSTS Cereals vs Ingred UnprocessedWheatBran',
        'type': 'general',
        'food codes':[
            57417000, # Cereal (Post Shredded Wheat)
            57341000, # Cereal (Post Shredded Wheat'n Bran)
            
            57601100, # Wheat bran, unprocessed
        ],
        'comparison base': 57601100, # Wheat bran, unprocessed
        #     57601100, # Wheat bran, unprocessed
        #     57604100, # Whole wheat, cracked
    },
    {
        'name': 'Lasagna meat and canned',
        'type': 'general',
        'food codes':[
            58130011, # Lasagna with meat
            58130013, # Lasagna with meat, canned
        ]
    },
    {
        'name': 'compare All Lasagna vs HomeRecipe',
        'type': 'home vs commercial',
        'food codes':[
            58130011, # Lasagna with meat
            58130013, # Lasagna with meat, canned
            58130014, # Lasagna with meat, from restaurant
            
            58130015, # Lasagna with meat, home recipe
        ],
        'comparison base': 58130015 # Lasagna with meat, home recipe
    },
    {
        'name': 'Lasagna ALL FOUR',
        'type': 'general',
        'food codes':[
            58130015, # Lasagna with meat, home recipe
            58130014, # Lasagna with meat, from restaurant

            58130011, # Lasagna with meat
            58130013, # Lasagna with meat, canned
        ]
    },
    {
        'name': 'Salsa home vs restaurant',
        'type': 'home vs commercial',
        'food codes':[
            74402200,  #Salsa, red, homemade
            74402150 # Salsa, red, commercially-prepared
        ],
        'comparison base': 74402200,  #Salsa, red, homemade
    },
    
    {
        'name': 'BeefNoodleSoup home vs restaurant',
        'type': 'home vs commercial',
        'food codes':[
            28310320, # Beef noodle soup, Puerto Rican style
            58402010, # Beef noodle soup, canned or ready-to-serve
            58402100, # Beef noodle soup, home recipe
        ],
        'comparison base': 58402100,  #Salsa, red, homemade
    },
]

def get_case_study(name):
    for case in case_studies:
        if case['name'] == name:
            return case
        
    return None

case_study = [c['name'] for c in case_studies][-1]

case_study = 'POST four cereals AND UnprocessedWheatBran'

case_study = get_case_study(case_study)

# load_data_main()


foods_df = fndds_cons_df[fndds_cons_df['Food code'].isin(case_study['food codes'])]

print(case_study['name'], '| TYPE:', case_study['type'])
foods_df
# Out:
# POST four cereals AND UnprocessedWheatBran | TYPE: general
#       Food code       FPS   min_FPS   std_FPS  \
# 4565  57230000   0.960333  0.953889  0.005969
# 4571  57237300   0.999889  0.999444  0.000248
# 4645  57341000   0.565796  0.330741  0.131864
# 4672  57417000   0.568500  0.212222  0.200677
# 4675  57601100   0.068167  0.041389  0.049966
#
#                                  Main food description  year     cat_digit_1  \
# 4565  Cereal (Post Grape-Nuts)                          2015  Grain Products
# 4571  Cereal (Post Honey Bunches of Oats with Almonds)  2015  Grain Products
# 4645  Cereal (Post Shredded Wheat'n Bran)               2015  Grain Products
# 4672  Cereal (Post Shredded Wheat)                      2015  Grain Products
# 4675  Wheat bran, unprocessed                           2015  Grain Products
#
#                                  cat_digit_2                cat_digit_3  \
# 4565  Cereals, not cooked or NS as to cooked  NaN
# 4571  Cereals, not cooked or NS as to cooked  NaN
# 4645  Cereals, not cooked or NS as to cooked  NaN
# 4672  Cereals, not cooked or NS as to cooked  NaN
# 4675  Cereals, not cooked or NS as to cooked  Cereal grains, not cooked
#
#      cat_digit_4 cat_digit_5  WWEIA Category number  \
# 4565  NaN         NaN         4604.0
# 4571  NaN         NaN         4604.0
# 4645  NaN         NaN         4604.0
# 4672  NaN         NaN         4604.0
# 4675  NaN         NaN         9999.0
#
#                            WWEIA Category description  year_WWEIA_category  \
# 4565  Ready-to-eat cereal, lower sugar (=<21.2g/100g)  2015.0
# 4571  Ready-to-eat cereal, lower sugar (=<21.2g/100g)  2015.0
# 4645  Ready-to-eat cereal, lower sugar (=<21.2g/100g)  2015.0
# 4672  Ready-to-eat cereal, lower sugar (=<21.2g/100g)  2015.0
# 4675  Not included in a food category                  2015.0
#
#                  n           se.n         Grams      Calories      se.Grams  \
# 4565  1.656857e+06  862321.482196  1.363823e+08  4.921889e+08  6.599260e+07
# 4571  4.198847e+06  938582.034788  2.295714e+08  9.396220e+08  5.478322e+07
# 4645  5.911034e+04  37205.588817   3.717913e+06  1.258864e+07  2.219281e+06
# 4672  1.333248e+06  330919.115972  5.455256e+07  1.876944e+08  1.713816e+07
# 4675  9.500213e+04  84014.929108   1.442167e+06  3.072026e+06  1.032577e+06
#
#        se.Calories  Protein  Total Fat  Carbohydrate  Alcohol  Water  \
# 4565  2.380722e+08  11.22    1.81       80.49         0.0      3.50
# 4571  2.242224e+08  7.70     7.30       79.60         0.0      2.90
# 4645  7.513263e+06  10.93    2.06       80.65         0.0      3.14
# 4672  5.892278e+07  11.58    2.06       80.18         0.0      4.55
# 4675  2.193691e+06  15.55    4.25       64.51         0.0      9.89
#
#       Caffeine  Theobromine  Sugars, total  Fiber, total dietary  Calcium  \
# 4565  0.0       0.0          8.86           13.0                  0.032
# 4571  0.0       0.0          20.00          5.5                   0.035
# 4645  0.0       0.0          0.75           14.7                  0.044
# 4672  0.0       0.0          0.92           12.4                  0.057
# 4675  0.0       0.0          0.41           42.8                  0.073
#
#          Iron  Magnesium  Phosphorus  Potassium  Sodium     Zinc    Copper  \
# 4565  0.02800  0.124      0.467       0.400      0.465   0.00207  0.000340
# 4571  0.03380  0.061      0.172       0.211      0.417   0.00090  0.000200
# 4645  0.00387  0.174      0.418       0.391      0.000   0.00313  0.000000
# 4672  0.00256  0.132      0.380       0.384      0.002   0.00297  0.000357
# 4675  0.01057  0.611      1.013       1.182      0.002   0.00727  0.000998
#
#       Selenium   Retinol  Carotene, beta  Carotene, alpha  \
# 4565  0.000009  0.000000  0.000002        0.000000
# 4571  0.000012  0.000675  0.000043        0.000028
# 4645  0.000008  0.000000  0.000000        0.000000
# 4672  0.000004  0.000000  0.000000        0.000000
# 4675  0.000078  0.000000  0.000006        0.000000
#
#       Vitamin E (alpha-tocopherol)  Vitamin D (D2 + D3)  Cryptoxanthin, beta  \
# 4565  0.00062                       0.000000             0.0
# 4571  0.00186                       0.000003             0.0
# 4645  0.00109                       0.000000             0.0
# 4672  0.00032                       0.000000             0.0
# 4675  0.00149                       0.000000             0.0
#
#       Lycopene  Lutein + zeaxanthin  Vitamin C   Thiamin  Riboflavin  \
# 4565  0.0       0.000166             0.0001     0.000650  0.000120
# 4571  0.0       0.000630             0.0000     0.001200  0.001300
# 4645  0.0       0.000236             0.0000     0.000200  0.000080
# 4672  0.0       0.000088             0.0000     0.000285  0.000090
# 4675  0.0       0.000240             0.0000     0.000523  0.000577
#
#         Niacin  Vitamin B-6  Folate, total  Vitamin B-12  Choline, total  \
# 4565  0.008620  0.000860     0.000345       0.000000      0.0319
# 4571  0.015600  0.001600     0.000625       0.000005      0.0214
# 4645  0.005200  0.000080     0.000030       0.000000      0.0231
# 4672  0.005950  0.000155     0.000042       0.000000      0.0231
# 4675  0.013578  0.001303     0.000079       0.000000      0.0744
#
#       Vitamin K (phylloquinone)  Folic acid  Folate, food  Vitamin E, added  \
# 4565  0.000002                   0.000326    0.000019      0.0
# 4571  0.000003                   0.000606    0.000019      0.0
# 4645  0.000002                   0.000000    0.000030      0.0
# 4672  0.000001                   0.000000    0.000042      0.0
# 4675  0.000002                   0.000000    0.000079      0.0
#
#       Vitamin B-12, added  Cholesterol  Fatty acids, total saturated    4:0  \
# 4565  0.000000             0.0          0.340                         0.000
# 4571  0.000005             0.0          0.800                         0.001
# 4645  0.000000             0.0          0.430                         0.000
# 4672  0.000000             0.0          0.405                         0.000
# 4675  0.000000             0.0          0.630                         0.000
#
#       6:0    8:0  10:0   12:0   14:0   16:0   18:0   18:1   18:2   18:3  \
# 4565  0.0  0.000  0.0   0.002  0.004  0.309  0.014  0.189  0.720  0.061
# 4571  0.0  0.000  0.0   0.001  0.003  0.606  0.133  3.956  1.974  0.126
# 4645  0.0  0.000  0.0   0.000  0.004  0.405  0.021  0.316  1.166  0.054
# 4672  0.0  0.012  0.0   0.000  0.002  0.372  0.019  0.278  1.188  0.070
# 4675  0.0  0.000  0.0   0.002  0.007  0.556  0.037  0.619  2.039  0.167
#
#        20:4  22:6 n-3   16:1  18:4   20:1  20:5 n-3   22:1  22:5 n-3  \
# 4565  0.000  0.0       0.003  0.0   0.004  0.0       0.000  0.0
# 4571  0.000  0.0       0.016  0.0   0.024  0.0       0.003  0.0
# 4645  0.000  0.0       0.014  0.0   0.000  0.0       0.000  0.0
# 4672  0.002  0.0       0.008  0.0   0.008  0.0       0.000  0.0
# 4675  0.005  0.0       0.017  0.0   0.000  0.0       0.000  0.0
#
#       Fatty acids, total monounsaturated  Fatty acids, total polyunsaturated  \
# 4565  0.210                               0.780
# 4571  4.000                               2.100
# 4645  0.330                               1.220
# 4672  0.295                               1.260
# 4675  0.637                               2.212
#
#       class  p1  p2  p3  p4  Total Vitamin A NOVA class
# 4565 NaN    NaN NaN NaN NaN NaN               NaN
# 4571 NaN    NaN NaN NaN NaN NaN               NaN
# 4645 NaN    NaN NaN NaN NaN NaN               NaN
# 4672 NaN    NaN NaN NaN NaN NaN               NaN
# 4675 NaN    NaN NaN NaN NaN NaN               NaN

# %%
[c for c in foods_df.columns if '4:' in c]
# Out:
# ['4:0', '14:0']

# %%
def prep_data_for_plot(foods_df, col_nuts):
    print('case_study:', case_study)
    
    foods_df = foods_df.copy()
    
    if bool((foods_df[col_nuts] == -20).any(axis=1).any()) is True:
        print('Already data is in log scale... going to convert back for showing actual values in hover')
        
        foods_df.loc[:, col_nuts] = foods_df.loc[:, col_nuts].replace(-20, np.nan).apply(np.exp).replace(np.nan, 0)
    
    #'THIS IS NEEDED FOR PLOTTING!:'
    
#     col_nuts = list(foods_df.loc[:, 'Protein':'Fatty acids, total polyunsaturated'].columns)
    
    if col_nuts[0] == 'Protein':
        col_nuts.reverse()
#     col_nuts.reverse()

    col_nut_code_dict = {col: i for i, col in enumerate(col_nuts)}
    rows = []

    def un_pivot(r):
        d = {
            'Food code': r['Food code'],
            'FPS': r['FPS'],
    #         'ens_FPS': r['ens_FPS'],
    #         'ens_min_FPS': r['ens_min_FPS'],
            'std_FPS': r['std_FPS'],
            'min_FPS': r['min_FPS'],
            'Main food description': r['Main food description']
        }

        for col in col_nuts:
            
            
            d_copy = d.copy()
            d_copy['nut name'] = col
            d_copy['nut code'] = col_nut_code_dict[col]
            d_copy['nut value'] = r[col]
            d_copy['hover'] = '{}: {}<br />{}<br />Food code:{}'.format(
                col, r[col], r['Main food description'], r['Food code'])
            
            
            if col == 'Calcium':
                d_copy['nut value'] = r[col]
            
            rows.append(d_copy)
            pass

        return r

    q=foods_df.apply(un_pivot, axis=1)

    plot_df = pd.DataFrame(rows).reset_index(drop=True)

    # transform
    plot_df['nut value grams'] = plot_df['nut value']
    
    plot_df['nut value'] = (
        plot_df['nut value']
        .apply(np.log)
        .replace([-np.inf, np.inf], -20)
        .replace(np.nan, -20)
    )
    
    return plot_df

# %% [markdown]
# # Plot Nutrients

# %%
[c['name'] for c in case_studies]
# Out:
# ['POST four cereals',
#  'POST WheatBran vs ShreddedWheat',
#  'POST four cereals AND UnprocessedWheatBran',
#  'compare POST four cereals vs UnprocessedWheatBran',
#  'POSTS Cereals vs Ingred UnprocessedWheatBran',
#  'Lasagna meat and canned',
#  'compare All Lasagna vs HomeRecipe',
#  'Lasagna ALL FOUR',
#  'Salsa home vs restaurant',
#  'BeefNoodleSoup home vs restaurant']

# %%
# case_study = 'POSTS Cereals vs Ingred UnprocessedWheatBran'
case_study = ['POST four cereals AND UnprocessedWheatBran', 'compare POST four cereals vs UnprocessedWheatBran'][1]
# case_study = ['Lasagna ALL FOUR', 'Lasagna meat and canned', 'compare All Lasagna vs HomeRecipe'][1]

compare_nuts = True

case_study = get_case_study(case_study)

print(case_study)

if 'Total isoflavones' in foods_df.columns:
    col_nuts = list(foods_df.loc[:, 'Protein':'Total isoflavones'].columns)
else:
    col_nuts = list(foods_df.loc[:, 'Protein':'Fatty acids, total polyunsaturated'].columns)

# load_data_main()
foods_df = (
    fndds_cons_df[fndds_cons_df['Food code'].isin(case_study['food codes'])]
#     .sort_values(by='FPS', ascending=False) # IF YOU SORT, WONT GET SAME ORDER AS SI
)

print('num nuts:', len(col_nuts))

foods_df[col_nuts]
# foods_df
# Out:
# {'name': 'compare POST four cereals vs UnprocessedWheatBran', 'type': 'general', 'food codes': [57237300, 57230000, 57417000, 57341000, 57601100], 'comparison base': 57601100}
# num nuts: 62
#       Protein  Total Fat  Carbohydrate  Alcohol  Water  Caffeine  Theobromine  \
# 4565  11.22    1.81       80.49         0.0      3.50   0.0       0.0
# 4571  7.70     7.30       79.60         0.0      2.90   0.0       0.0
# 4645  10.93    2.06       80.65         0.0      3.14   0.0       0.0
# 4672  11.58    2.06       80.18         0.0      4.55   0.0       0.0
# 4675  15.55    4.25       64.51         0.0      9.89   0.0       0.0
#
#       Sugars, total  Fiber, total dietary  Calcium     Iron  Magnesium  \
# 4565  8.86           13.0                  0.032    0.02800  0.124
# 4571  20.00          5.5                   0.035    0.03380  0.061
# 4645  0.75           14.7                  0.044    0.00387  0.174
# 4672  0.92           12.4                  0.057    0.00256  0.132
# 4675  0.41           42.8                  0.073    0.01057  0.611
#
#       Phosphorus  Potassium  Sodium     Zinc    Copper  Selenium   Retinol  \
# 4565  0.467       0.400      0.465   0.00207  0.000340  0.000009  0.000000
# 4571  0.172       0.211      0.417   0.00090  0.000200  0.000012  0.000675
# 4645  0.418       0.391      0.000   0.00313  0.000000  0.000008  0.000000
# 4672  0.380       0.384      0.002   0.00297  0.000357  0.000004  0.000000
# 4675  1.013       1.182      0.002   0.00727  0.000998  0.000078  0.000000
#
#       Carotene, beta  Carotene, alpha  Vitamin E (alpha-tocopherol)  \
# 4565  0.000002        0.000000         0.00062
# 4571  0.000043        0.000028         0.00186
# 4645  0.000000        0.000000         0.00109
# 4672  0.000000        0.000000         0.00032
# 4675  0.000006        0.000000         0.00149
#
#       Vitamin D (D2 + D3)  Cryptoxanthin, beta  Lycopene  Lutein + zeaxanthin  \
# 4565  0.000000             0.0                  0.0       0.000166
# 4571  0.000003             0.0                  0.0       0.000630
# 4645  0.000000             0.0                  0.0       0.000236
# 4672  0.000000             0.0                  0.0       0.000088
# 4675  0.000000             0.0                  0.0       0.000240
#
#       Vitamin C   Thiamin  Riboflavin    Niacin  Vitamin B-6  Folate, total  \
# 4565  0.0001     0.000650  0.000120    0.008620  0.000860     0.000345
# 4571  0.0000     0.001200  0.001300    0.015600  0.001600     0.000625
# 4645  0.0000     0.000200  0.000080    0.005200  0.000080     0.000030
# 4672  0.0000     0.000285  0.000090    0.005950  0.000155     0.000042
# 4675  0.0000     0.000523  0.000577    0.013578  0.001303     0.000079
#
#       Vitamin B-12  Choline, total  Vitamin K (phylloquinone)  Folic acid  \
# 4565  0.000000      0.0319          0.000002                   0.000326
# 4571  0.000005      0.0214          0.000003                   0.000606
# 4645  0.000000      0.0231          0.000002                   0.000000
# 4672  0.000000      0.0231          0.000001                   0.000000
# 4675  0.000000      0.0744          0.000002                   0.000000
#
#       Folate, food  Vitamin E, added  Vitamin B-12, added  Cholesterol  \
# 4565  0.000019      0.0               0.000000             0.0
# 4571  0.000019      0.0               0.000005             0.0
# 4645  0.000030      0.0               0.000000             0.0
# 4672  0.000042      0.0               0.000000             0.0
# 4675  0.000079      0.0               0.000000             0.0
#
#       Fatty acids, total saturated    4:0  6:0    8:0  10:0   12:0   14:0  \
# 4565  0.340                         0.000  0.0  0.000  0.0   0.002  0.004
# 4571  0.800                         0.001  0.0  0.000  0.0   0.001  0.003
# 4645  0.430                         0.000  0.0  0.000  0.0   0.000  0.004
# 4672  0.405                         0.000  0.0  0.012  0.0   0.000  0.002
# 4675  0.630                         0.000  0.0  0.000  0.0   0.002  0.007
#
#        16:0   18:0   18:1   18:2   18:3   20:4  22:6 n-3   16:1  18:4   20:1  \
# 4565  0.309  0.014  0.189  0.720  0.061  0.000  0.0       0.003  0.0   0.004
# 4571  0.606  0.133  3.956  1.974  0.126  0.000  0.0       0.016  0.0   0.024
# 4645  0.405  0.021  0.316  1.166  0.054  0.000  0.0       0.014  0.0   0.000
# 4672  0.372  0.019  0.278  1.188  0.070  0.002  0.0       0.008  0.0   0.008
# 4675  0.556  0.037  0.619  2.039  0.167  0.005  0.0       0.017  0.0   0.000
#
#       20:5 n-3   22:1  22:5 n-3  Fatty acids, total monounsaturated  \
# 4565  0.0       0.000  0.0       0.210
# 4571  0.0       0.003  0.0       4.000
# 4645  0.0       0.000  0.0       0.330
# 4672  0.0       0.000  0.0       0.295
# 4675  0.0       0.000  0.0       0.637
#
#       Fatty acids, total polyunsaturated
# 4565  0.780
# 4571  2.100
# 4645  1.220
# 4672  1.260
# 4675  2.212

# %%
'''
log(items) - log(base)
'''

# foods_cmp_df = foods_df[col_nuts]

if 'comparison base' in case_study and case_study['comparison base'] is not None:
    compare_nuts = True
    foods_cmp_df = None

if compare_nuts:
    mask_compare_to = foods_df['Food code'] != case_study['comparison base']

    foods_cmp_df = (
        foods_df.loc[mask_compare_to, col_nuts] / 
        foods_df.loc[foods_df['Food code'] == case_study['comparison base'], col_nuts].iloc[0]
    )

    foods_cmp_df = foods_cmp_df.replace([np.inf, -np.inf], None)

    nan_cols = [i for i in foods_cmp_df.columns if foods_cmp_df[i].isnull().any()]
    
    print('compare_nuts:', compare_nuts)
    print(len(foods_cmp_df[col_nuts]))
    pass
# Out:
# compare_nuts: True
# 4

# %%
'''Assign log of devisions for targeted items'''

if compare_nuts:
    foods_df.loc[mask_compare_to, col_nuts] = foods_cmp_df.loc[:, col_nuts]
    
    foods_df = foods_df[foods_df['Food code'] != case_study['comparison base']]
    
foods_df[col_nuts]
# Out:
# C:\anaconda3\envs\foodome\lib\site-packages\pandas\core\indexing.py:1787: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)
#        Protein  Total Fat  Carbohydrate  Alcohol     Water  Caffeine  \
# 4565  0.721543  0.425882   1.247714     NaN       0.353893 NaN
# 4571  0.495177  1.717647   1.233917     NaN       0.293225 NaN
# 4645  0.702894  0.484706   1.250194     NaN       0.317492 NaN
# 4672  0.744695  0.484706   1.242908     NaN       0.460061 NaN
#
#       Theobromine  Sugars, total  Fiber, total dietary   Calcium      Iron  \
# 4565 NaN           21.609756      0.303738              0.438356  2.649007
# 4571 NaN           48.780488      0.128505              0.479452  3.197729
# 4645 NaN           1.829268       0.343458              0.602740  0.366131
# 4672 NaN           2.243902       0.289720              0.780822  0.242195
#
#       Magnesium  Phosphorus  Potassium  Sodium      Zinc    Copper  Selenium  \
# 4565  0.202946   0.461007    0.338409   232.5   0.284732  0.340681  0.117268
# 4571  0.099836   0.169793    0.178511   208.5   0.123796  0.200401  0.154639
# 4645  0.284779   0.412636    0.330795   0.0     0.430536  0.000000  0.105670
# 4672  0.216039   0.375123    0.324873   1.0     0.408528  0.357715  0.056701
#
#       Retinol  Carotene, beta  Carotene, alpha  Vitamin E (alpha-tocopherol)  \
# 4565 NaN       0.333333       NaN               0.416107
# 4571 NaN       7.166667       NaN               1.248322
# 4645 NaN       0.000000       NaN               0.731544
# 4672 NaN       0.000000       NaN               0.214765
#
#       Vitamin D (D2 + D3)  Cryptoxanthin, beta  Lycopene  Lutein + zeaxanthin  \
# 4565 NaN                  NaN                  NaN        0.691667
# 4571 NaN                  NaN                  NaN        2.625000
# 4645 NaN                  NaN                  NaN        0.983333
# 4672 NaN                  NaN                  NaN        0.366667
#
#       Vitamin C   Thiamin  Riboflavin    Niacin  Vitamin B-6  Folate, total  \
# 4565  inf        1.242830  0.207972    0.634850  0.660015     4.367089
# 4571 NaN         2.294455  2.253033    1.148917  1.227936     7.911392
# 4645 NaN         0.382409  0.138648    0.382972  0.061397     0.379747
# 4672 NaN         0.544933  0.155979    0.438209  0.118956     0.531646
#
#       Vitamin B-12  Choline, total  Vitamin K (phylloquinone)  Folic acid  \
# 4565 NaN            0.428763        1.052632                   inf
# 4571 NaN            0.287634        1.631579                   inf
# 4645 NaN            0.310484        1.052632                  NaN
# 4672 NaN            0.310484        0.736842                  NaN
#
#       Folate, food  Vitamin E, added  Vitamin B-12, added  Cholesterol  \
# 4565  0.240506     NaN               NaN                  NaN
# 4571  0.240506     NaN               NaN                  NaN
# 4645  0.379747     NaN               NaN                  NaN
# 4672  0.531646     NaN               NaN                  NaN
#
#       Fatty acids, total saturated  4:0  6:0  8:0  10:0  12:0      14:0  \
# 4565  0.539683                     NaN  NaN  NaN  NaN    1.0   0.571429
# 4571  1.269841                     NaN  NaN  NaN  NaN    0.5   0.428571
# 4645  0.682540                     NaN  NaN  NaN  NaN    0.0   0.571429
# 4672  0.642857                     NaN  NaN  NaN  NaN    0.0   0.285714
#
#           16:0      18:0      18:1      18:2      18:3  20:4  22:6 n-3  \
# 4565  0.555755  0.378378  0.305331  0.353114  0.365269  0.0  NaN
# 4571  1.089928  3.594595  6.390953  0.968122  0.754491  0.0  NaN
# 4645  0.728417  0.567568  0.510501  0.571849  0.323353  0.0  NaN
# 4672  0.669065  0.513514  0.449111  0.582639  0.419162  0.4  NaN
#
#           16:1  18:4  20:1  20:5 n-3  22:1  22:5 n-3  \
# 4565  0.176471 NaN    inf  NaN       NaN   NaN
# 4571  0.941176 NaN    inf  NaN       NaN   NaN
# 4645  0.823529 NaN   NaN   NaN       NaN   NaN
# 4672  0.470588 NaN   NaN   NaN       NaN   NaN
#
#       Fatty acids, total monounsaturated  Fatty acids, total polyunsaturated
# 4565  0.329670                            0.352622
# 4571  6.279435                            0.949367
# 4645  0.518053                            0.551537
# 4672  0.463108                            0.569620

# %%
'''Only plot items that we have comparision (not divided by zero)'''
if compare_nuts:
#     col_nuts = [c for c in col_nuts if c not in nan_cols]
    col_nuts = col_nuts
    pass

len(col_nuts)
# Out:
# 62

# %%
np.log(-2.120263536)
# Out:
# <ipython-input-25-86c13a1633f2>:1: RuntimeWarning: invalid value encountered in log
#   np.log(-2.120263536)
# nan

# %%
foods_df.loc[:, col_nuts].replace(-20, np.nan).apply(np.exp).replace(np.nan, 0)
(foods_df[col_nuts] == -20).any(axis=1).any()
bool((foods_df[col_nuts] == -20).any(axis=1).any()) is True
# Out:
# False

# %%
'''Prepare data for the plot'''
plot_df = prep_data_for_plot(foods_df=foods_df, col_nuts=col_nuts)

print(case_study['name'], '| TYPE:', case_study['type'])
# foods_df
plot_df
# Out:
# case_study: {'name': 'compare POST four cereals vs UnprocessedWheatBran', 'type': 'general', 'food codes': [57237300, 57230000, 57417000, 57341000, 57601100], 'comparison base': 57601100}
# compare POST four cereals vs UnprocessedWheatBran | TYPE: general
#      Food code       FPS   std_FPS   min_FPS  \
# 0    57230000   0.960333  0.005969  0.953889
# 1    57230000   0.960333  0.005969  0.953889
# 2    57230000   0.960333  0.005969  0.953889
# 3    57230000   0.960333  0.005969  0.953889
# 4    57230000   0.960333  0.005969  0.953889
# 5    57230000   0.960333  0.005969  0.953889
# 6    57230000   0.960333  0.005969  0.953889
# 7    57230000   0.960333  0.005969  0.953889
# 8    57230000   0.960333  0.005969  0.953889
# 9    57230000   0.960333  0.005969  0.953889
# 10   57230000   0.960333  0.005969  0.953889
# 11   57230000   0.960333  0.005969  0.953889
# 12   57230000   0.960333  0.005969  0.953889
# 13   57230000   0.960333  0.005969  0.953889
# 14   57230000   0.960333  0.005969  0.953889
# 15   57230000   0.960333  0.005969  0.953889
# 16   57230000   0.960333  0.005969  0.953889
# 17   57230000   0.960333  0.005969  0.953889
# 18   57230000   0.960333  0.005969  0.953889
# 19   57230000   0.960333  0.005969  0.953889
# 20   57230000   0.960333  0.005969  0.953889
# 21   57230000   0.960333  0.005969  0.953889
# 22   57230000   0.960333  0.005969  0.953889
# 23   57230000   0.960333  0.005969  0.953889
# 24   57230000   0.960333  0.005969  0.953889
# 25   57230000   0.960333  0.005969  0.953889
# 26   57230000   0.960333  0.005969  0.953889
# 27   57230000   0.960333  0.005969  0.953889
# 28   57230000   0.960333  0.005969  0.953889
# 29   57230000   0.960333  0.005969  0.953889
# 30   57230000   0.960333  0.005969  0.953889
# 31   57230000   0.960333  0.005969  0.953889
# 32   57230000   0.960333  0.005969  0.953889
# 33   57230000   0.960333  0.005969  0.953889
# 34   57230000   0.960333  0.005969  0.953889
# 35   57230000   0.960333  0.005969  0.953889
# 36   57230000   0.960333  0.005969  0.953889
# 37   57230000   0.960333  0.005969  0.953889
# 38   57230000   0.960333  0.005969  0.953889
# 39   57230000   0.960333  0.005969  0.953889
# 40   57230000   0.960333  0.005969  0.953889
# 41   57230000   0.960333  0.005969  0.953889
# 42   57230000   0.960333  0.005969  0.953889
# 43   57230000   0.960333  0.005969  0.953889
# 44   57230000   0.960333  0.005969  0.953889
# 45   57230000   0.960333  0.005969  0.953889
# 46   57230000   0.960333  0.005969  0.953889
# 47   57230000   0.960333  0.005969  0.953889
# 48   57230000   0.960333  0.005969  0.953889
# 49   57230000   0.960333  0.005969  0.953889
# 50   57230000   0.960333  0.005969  0.953889
# 51   57230000   0.960333  0.005969  0.953889
# 52   57230000   0.960333  0.005969  0.953889
# 53   57230000   0.960333  0.005969  0.953889
# 54   57230000   0.960333  0.005969  0.953889
# 55   57230000   0.960333  0.005969  0.953889
# 56   57230000   0.960333  0.005969  0.953889
# 57   57230000   0.960333  0.005969  0.953889
# 58   57230000   0.960333  0.005969  0.953889
# 59   57230000   0.960333  0.005969  0.953889
# 60   57230000   0.960333  0.005969  0.953889
# 61   57230000   0.960333  0.005969  0.953889
# 62   57237300   0.999889  0.000248  0.999444
# 63   57237300   0.999889  0.000248  0.999444
# 64   57237300   0.999889  0.000248  0.999444
# 65   57237300   0.999889  0.000248  0.999444
# 66   57237300   0.999889  0.000248  0.999444
# 67   57237300   0.999889  0.000248  0.999444
# 68   57237300   0.999889  0.000248  0.999444
# 69   57237300   0.999889  0.000248  0.999444
# 70   57237300   0.999889  0.000248  0.999444
# 71   57237300   0.999889  0.000248  0.999444
# 72   57237300   0.999889  0.000248  0.999444
# 73   57237300   0.999889  0.000248  0.999444
# 74   57237300   0.999889  0.000248  0.999444
# 75   57237300   0.999889  0.000248  0.999444
# 76   57237300   0.999889  0.000248  0.999444
# 77   57237300   0.999889  0.000248  0.999444
# 78   57237300   0.999889  0.000248  0.999444
# 79   57237300   0.999889  0.000248  0.999444
# 80   57237300   0.999889  0.000248  0.999444
# 81   57237300   0.999889  0.000248  0.999444
# 82   57237300   0.999889  0.000248  0.999444
# 83   57237300   0.999889  0.000248  0.999444
# 84   57237300   0.999889  0.000248  0.999444
# 85   57237300   0.999889  0.000248  0.999444
# 86   57237300   0.999889  0.000248  0.999444
# 87   57237300   0.999889  0.000248  0.999444
# 88   57237300   0.999889  0.000248  0.999444
# 89   57237300   0.999889  0.000248  0.999444
# 90   57237300   0.999889  0.000248  0.999444
# 91   57237300   0.999889  0.000248  0.999444
# 92   57237300   0.999889  0.000248  0.999444
# 93   57237300   0.999889  0.000248  0.999444
# 94   57237300   0.999889  0.000248  0.999444
# 95   57237300   0.999889  0.000248  0.999444
# 96   57237300   0.999889  0.000248  0.999444
# 97   57237300   0.999889  0.000248  0.999444
# 98   57237300   0.999889  0.000248  0.999444
# 99   57237300   0.999889  0.000248  0.999444
# 100  57237300   0.999889  0.000248  0.999444
# 101  57237300   0.999889  0.000248  0.999444
# 102  57237300   0.999889  0.000248  0.999444
# 103  57237300   0.999889  0.000248  0.999444
# 104  57237300   0.999889  0.000248  0.999444
# 105  57237300   0.999889  0.000248  0.999444
# 106  57237300   0.999889  0.000248  0.999444
# 107  57237300   0.999889  0.000248  0.999444
# 108  57237300   0.999889  0.000248  0.999444
# 109  57237300   0.999889  0.000248  0.999444
# 110  57237300   0.999889  0.000248  0.999444
# 111  57237300   0.999889  0.000248  0.999444
# 112  57237300   0.999889  0.000248  0.999444
# 113  57237300   0.999889  0.000248  0.999444
# 114  57237300   0.999889  0.000248  0.999444
# 115  57237300   0.999889  0.000248  0.999444
# 116  57237300   0.999889  0.000248  0.999444
# 117  57237300   0.999889  0.000248  0.999444
# 118  57237300   0.999889  0.000248  0.999444
# 119  57237300   0.999889  0.000248  0.999444
# 120  57237300   0.999889  0.000248  0.999444
# 121  57237300   0.999889  0.000248  0.999444
# 122  57237300   0.999889  0.000248  0.999444
# 123  57237300   0.999889  0.000248  0.999444
# 124  57341000   0.565796  0.131864  0.330741
# 125  57341000   0.565796  0.131864  0.330741
# 126  57341000   0.565796  0.131864  0.330741
# 127  57341000   0.565796  0.131864  0.330741
# 128  57341000   0.565796  0.131864  0.330741
# 129  57341000   0.565796  0.131864  0.330741
# 130  57341000   0.565796  0.131864  0.330741
# 131  57341000   0.565796  0.131864  0.330741
# 132  57341000   0.565796  0.131864  0.330741
# 133  57341000   0.565796  0.131864  0.330741
# 134  57341000   0.565796  0.131864  0.330741
# 135  57341000   0.565796  0.131864  0.330741
# 136  57341000   0.565796  0.131864  0.330741
# 137  57341000   0.565796  0.131864  0.330741
# 138  57341000   0.565796  0.131864  0.330741
# 139  57341000   0.565796  0.131864  0.330741
# 140  57341000   0.565796  0.131864  0.330741
# 141  57341000   0.565796  0.131864  0.330741
# 142  57341000   0.565796  0.131864  0.330741
# 143  57341000   0.565796  0.131864  0.330741
# 144  57341000   0.565796  0.131864  0.330741
# 145  57341000   0.565796  0.131864  0.330741
# 146  57341000   0.565796  0.131864  0.330741
# 147  57341000   0.565796  0.131864  0.330741
# 148  57341000   0.565796  0.131864  0.330741
# 149  57341000   0.565796  0.131864  0.330741
# 150  57341000   0.565796  0.131864  0.330741
# 151  57341000   0.565796  0.131864  0.330741
# 152  57341000   0.565796  0.131864  0.330741
# 153  57341000   0.565796  0.131864  0.330741
# 154  57341000   0.565796  0.131864  0.330741
# 155  57341000   0.565796  0.131864  0.330741
# 156  57341000   0.565796  0.131864  0.330741
# 157  57341000   0.565796  0.131864  0.330741
# 158  57341000   0.565796  0.131864  0.330741
# 159  57341000   0.565796  0.131864  0.330741
# 160  57341000   0.565796  0.131864  0.330741
# 161  57341000   0.565796  0.131864  0.330741
# 162  57341000   0.565796  0.131864  0.330741
# 163  57341000   0.565796  0.131864  0.330741
# 164  57341000   0.565796  0.131864  0.330741
# 165  57341000   0.565796  0.131864  0.330741
# 166  57341000   0.565796  0.131864  0.330741
# 167  57341000   0.565796  0.131864  0.330741
# 168  57341000   0.565796  0.131864  0.330741
# 169  57341000   0.565796  0.131864  0.330741
# 170  57341000   0.565796  0.131864  0.330741
# 171  57341000   0.565796  0.131864  0.330741
# 172  57341000   0.565796  0.131864  0.330741
# 173  57341000   0.565796  0.131864  0.330741
# 174  57341000   0.565796  0.131864  0.330741
# 175  57341000   0.565796  0.131864  0.330741
# 176  57341000   0.565796  0.131864  0.330741
# 177  57341000   0.565796  0.131864  0.330741
# 178  57341000   0.565796  0.131864  0.330741
# 179  57341000   0.565796  0.131864  0.330741
# 180  57341000   0.565796  0.131864  0.330741
# 181  57341000   0.565796  0.131864  0.330741
# 182  57341000   0.565796  0.131864  0.330741
# 183  57341000   0.565796  0.131864  0.330741
# 184  57341000   0.565796  0.131864  0.330741
# 185  57341000   0.565796  0.131864  0.330741
# 186  57417000   0.568500  0.200677  0.212222
# 187  57417000   0.568500  0.200677  0.212222
# 188  57417000   0.568500  0.200677  0.212222
# 189  57417000   0.568500  0.200677  0.212222
# 190  57417000   0.568500  0.200677  0.212222
# 191  57417000   0.568500  0.200677  0.212222
# 192  57417000   0.568500  0.200677  0.212222
# 193  57417000   0.568500  0.200677  0.212222
# 194  57417000   0.568500  0.200677  0.212222
# 195  57417000   0.568500  0.200677  0.212222
# 196  57417000   0.568500  0.200677  0.212222
# 197  57417000   0.568500  0.200677  0.212222
# 198  57417000   0.568500  0.200677  0.212222
# 199  57417000   0.568500  0.200677  0.212222
# 200  57417000   0.568500  0.200677  0.212222
# 201  57417000   0.568500  0.200677  0.212222
# 202  57417000   0.568500  0.200677  0.212222
# 203  57417000   0.568500  0.200677  0.212222
# 204  57417000   0.568500  0.200677  0.212222
# 205  57417000   0.568500  0.200677  0.212222
# 206  57417000   0.568500  0.200677  0.212222
# 207  57417000   0.568500  0.200677  0.212222
# 208  57417000   0.568500  0.200677  0.212222
# 209  57417000   0.568500  0.200677  0.212222
# 210  57417000   0.568500  0.200677  0.212222
# 211  57417000   0.568500  0.200677  0.212222
# 212  57417000   0.568500  0.200677  0.212222
# 213  57417000   0.568500  0.200677  0.212222
# 214  57417000   0.568500  0.200677  0.212222
# 215  57417000   0.568500  0.200677  0.212222
# 216  57417000   0.568500  0.200677  0.212222
# 217  57417000   0.568500  0.200677  0.212222
# 218  57417000   0.568500  0.200677  0.212222
# 219  57417000   0.568500  0.200677  0.212222
# 220  57417000   0.568500  0.200677  0.212222
# 221  57417000   0.568500  0.200677  0.212222
# 222  57417000   0.568500  0.200677  0.212222
# 223  57417000   0.568500  0.200677  0.212222
# 224  57417000   0.568500  0.200677  0.212222
# 225  57417000   0.568500  0.200677  0.212222
# 226  57417000   0.568500  0.200677  0.212222
# 227  57417000   0.568500  0.200677  0.212222
# 228  57417000   0.568500  0.200677  0.212222
# 229  57417000   0.568500  0.200677  0.212222
# 230  57417000   0.568500  0.200677  0.212222
# 231  57417000   0.568500  0.200677  0.212222
# 232  57417000   0.568500  0.200677  0.212222
# 233  57417000   0.568500  0.200677  0.212222
# 234  57417000   0.568500  0.200677  0.212222
# 235  57417000   0.568500  0.200677  0.212222
# 236  57417000   0.568500  0.200677  0.212222
# 237  57417000   0.568500  0.200677  0.212222
# 238  57417000   0.568500  0.200677  0.212222
# 239  57417000   0.568500  0.200677  0.212222
# 240  57417000   0.568500  0.200677  0.212222
# 241  57417000   0.568500  0.200677  0.212222
# 242  57417000   0.568500  0.200677  0.212222
# 243  57417000   0.568500  0.200677  0.212222
# 244  57417000   0.568500  0.200677  0.212222
# 245  57417000   0.568500  0.200677  0.212222
# 246  57417000   0.568500  0.200677  0.212222
# 247  57417000   0.568500  0.200677  0.212222
#
#                                 Main food description  \
# 0    Cereal (Post Grape-Nuts)
# 1    Cereal (Post Grape-Nuts)
# 2    Cereal (Post Grape-Nuts)
# 3    Cereal (Post Grape-Nuts)
# 4    Cereal (Post Grape-Nuts)
# 5    Cereal (Post Grape-Nuts)
# 6    Cereal (Post Grape-Nuts)
# 7    Cereal (Post Grape-Nuts)
# 8    Cereal (Post Grape-Nuts)
# 9    Cereal (Post Grape-Nuts)
# 10   Cereal (Post Grape-Nuts)
# 11   Cereal (Post Grape-Nuts)
# 12   Cereal (Post Grape-Nuts)
# 13   Cereal (Post Grape-Nuts)
# 14   Cereal (Post Grape-Nuts)
# 15   Cereal (Post Grape-Nuts)
# 16   Cereal (Post Grape-Nuts)
# 17   Cereal (Post Grape-Nuts)
# 18   Cereal (Post Grape-Nuts)
# 19   Cereal (Post Grape-Nuts)
# 20   Cereal (Post Grape-Nuts)
# 21   Cereal (Post Grape-Nuts)
# 22   Cereal (Post Grape-Nuts)
# 23   Cereal (Post Grape-Nuts)
# 24   Cereal (Post Grape-Nuts)
# 25   Cereal (Post Grape-Nuts)
# 26   Cereal (Post Grape-Nuts)
# 27   Cereal (Post Grape-Nuts)
# 28   Cereal (Post Grape-Nuts)
# 29   Cereal (Post Grape-Nuts)
# 30   Cereal (Post Grape-Nuts)
# 31   Cereal (Post Grape-Nuts)
# 32   Cereal (Post Grape-Nuts)
# 33   Cereal (Post Grape-Nuts)
# 34   Cereal (Post Grape-Nuts)
# 35   Cereal (Post Grape-Nuts)
# 36   Cereal (Post Grape-Nuts)
# 37   Cereal (Post Grape-Nuts)
# 38   Cereal (Post Grape-Nuts)
# 39   Cereal (Post Grape-Nuts)
# 40   Cereal (Post Grape-Nuts)
# 41   Cereal (Post Grape-Nuts)
# 42   Cereal (Post Grape-Nuts)
# 43   Cereal (Post Grape-Nuts)
# 44   Cereal (Post Grape-Nuts)
# 45   Cereal (Post Grape-Nuts)
# 46   Cereal (Post Grape-Nuts)
# 47   Cereal (Post Grape-Nuts)
# 48   Cereal (Post Grape-Nuts)
# 49   Cereal (Post Grape-Nuts)
# 50   Cereal (Post Grape-Nuts)
# 51   Cereal (Post Grape-Nuts)
# 52   Cereal (Post Grape-Nuts)
# 53   Cereal (Post Grape-Nuts)
# 54   Cereal (Post Grape-Nuts)
# 55   Cereal (Post Grape-Nuts)
# 56   Cereal (Post Grape-Nuts)
# 57   Cereal (Post Grape-Nuts)
# 58   Cereal (Post Grape-Nuts)
# 59   Cereal (Post Grape-Nuts)
# 60   Cereal (Post Grape-Nuts)
# 61   Cereal (Post Grape-Nuts)
# 62   Cereal (Post Honey Bunches of Oats with Almonds)
# 63   Cereal (Post Honey Bunches of Oats with Almonds)
# 64   Cereal (Post Honey Bunches of Oats with Almonds)
# 65   Cereal (Post Honey Bunches of Oats with Almonds)
# 66   Cereal (Post Honey Bunches of Oats with Almonds)
# 67   Cereal (Post Honey Bunches of Oats with Almonds)
# 68   Cereal (Post Honey Bunches of Oats with Almonds)
# 69   Cereal (Post Honey Bunches of Oats with Almonds)
# 70   Cereal (Post Honey Bunches of Oats with Almonds)
# 71   Cereal (Post Honey Bunches of Oats with Almonds)
# 72   Cereal (Post Honey Bunches of Oats with Almonds)
# 73   Cereal (Post Honey Bunches of Oats with Almonds)
# 74   Cereal (Post Honey Bunches of Oats with Almonds)
# 75   Cereal (Post Honey Bunches of Oats with Almonds)
# 76   Cereal (Post Honey Bunches of Oats with Almonds)
# 77   Cereal (Post Honey Bunches of Oats with Almonds)
# 78   Cereal (Post Honey Bunches of Oats with Almonds)
# 79   Cereal (Post Honey Bunches of Oats with Almonds)
# 80   Cereal (Post Honey Bunches of Oats with Almonds)
# 81   Cereal (Post Honey Bunches of Oats with Almonds)
# 82   Cereal (Post Honey Bunches of Oats with Almonds)
# 83   Cereal (Post Honey Bunches of Oats with Almonds)
# 84   Cereal (Post Honey Bunches of Oats with Almonds)
# 85   Cereal (Post Honey Bunches of Oats with Almonds)
# 86   Cereal (Post Honey Bunches of Oats with Almonds)
# 87   Cereal (Post Honey Bunches of Oats with Almonds)
# 88   Cereal (Post Honey Bunches of Oats with Almonds)
# 89   Cereal (Post Honey Bunches of Oats with Almonds)
# 90   Cereal (Post Honey Bunches of Oats with Almonds)
# 91   Cereal (Post Honey Bunches of Oats with Almonds)
# 92   Cereal (Post Honey Bunches of Oats with Almonds)
# 93   Cereal (Post Honey Bunches of Oats with Almonds)
# 94   Cereal (Post Honey Bunches of Oats with Almonds)
# 95   Cereal (Post Honey Bunches of Oats with Almonds)
# 96   Cereal (Post Honey Bunches of Oats with Almonds)
# 97   Cereal (Post Honey Bunches of Oats with Almonds)
# 98   Cereal (Post Honey Bunches of Oats with Almonds)
# 99   Cereal (Post Honey Bunches of Oats with Almonds)
# 100  Cereal (Post Honey Bunches of Oats with Almonds)
# 101  Cereal (Post Honey Bunches of Oats with Almonds)
# 102  Cereal (Post Honey Bunches of Oats with Almonds)
# 103  Cereal (Post Honey Bunches of Oats with Almonds)
# 104  Cereal (Post Honey Bunches of Oats with Almonds)
# 105  Cereal (Post Honey Bunches of Oats with Almonds)
# 106  Cereal (Post Honey Bunches of Oats with Almonds)
# 107  Cereal (Post Honey Bunches of Oats with Almonds)
# 108  Cereal (Post Honey Bunches of Oats with Almonds)
# 109  Cereal (Post Honey Bunches of Oats with Almonds)
# 110  Cereal (Post Honey Bunches of Oats with Almonds)
# 111  Cereal (Post Honey Bunches of Oats with Almonds)
# 112  Cereal (Post Honey Bunches of Oats with Almonds)
# 113  Cereal (Post Honey Bunches of Oats with Almonds)
# 114  Cereal (Post Honey Bunches of Oats with Almonds)
# 115  Cereal (Post Honey Bunches of Oats with Almonds)
# 116  Cereal (Post Honey Bunches of Oats with Almonds)
# 117  Cereal (Post Honey Bunches of Oats with Almonds)
# 118  Cereal (Post Honey Bunches of Oats with Almonds)
# 119  Cereal (Post Honey Bunches of Oats with Almonds)
# 120  Cereal (Post Honey Bunches of Oats with Almonds)
# 121  Cereal (Post Honey Bunches of Oats with Almonds)
# 122  Cereal (Post Honey Bunches of Oats with Almonds)
# 123  Cereal (Post Honey Bunches of Oats with Almonds)
# 124  Cereal (Post Shredded Wheat'n Bran)
# 125  Cereal (Post Shredded Wheat'n Bran)
# 126  Cereal (Post Shredded Wheat'n Bran)
# 127  Cereal (Post Shredded Wheat'n Bran)
# 128  Cereal (Post Shredded Wheat'n Bran)
# 129  Cereal (Post Shredded Wheat'n Bran)
# 130  Cereal (Post Shredded Wheat'n Bran)
# 131  Cereal (Post Shredded Wheat'n Bran)
# 132  Cereal (Post Shredded Wheat'n Bran)
# 133  Cereal (Post Shredded Wheat'n Bran)
# 134  Cereal (Post Shredded Wheat'n Bran)
# 135  Cereal (Post Shredded Wheat'n Bran)
# 136  Cereal (Post Shredded Wheat'n Bran)
# 137  Cereal (Post Shredded Wheat'n Bran)
# 138  Cereal (Post Shredded Wheat'n Bran)
# 139  Cereal (Post Shredded Wheat'n Bran)
# 140  Cereal (Post Shredded Wheat'n Bran)
# 141  Cereal (Post Shredded Wheat'n Bran)
# 142  Cereal (Post Shredded Wheat'n Bran)
# 143  Cereal (Post Shredded Wheat'n Bran)
# 144  Cereal (Post Shredded Wheat'n Bran)
# 145  Cereal (Post Shredded Wheat'n Bran)
# 146  Cereal (Post Shredded Wheat'n Bran)
# 147  Cereal (Post Shredded Wheat'n Bran)
# 148  Cereal (Post Shredded Wheat'n Bran)
# 149  Cereal (Post Shredded Wheat'n Bran)
# 150  Cereal (Post Shredded Wheat'n Bran)
# 151  Cereal (Post Shredded Wheat'n Bran)
# 152  Cereal (Post Shredded Wheat'n Bran)
# 153  Cereal (Post Shredded Wheat'n Bran)
# 154  Cereal (Post Shredded Wheat'n Bran)
# 155  Cereal (Post Shredded Wheat'n Bran)
# 156  Cereal (Post Shredded Wheat'n Bran)
# 157  Cereal (Post Shredded Wheat'n Bran)
# 158  Cereal (Post Shredded Wheat'n Bran)
# 159  Cereal (Post Shredded Wheat'n Bran)
# 160  Cereal (Post Shredded Wheat'n Bran)
# 161  Cereal (Post Shredded Wheat'n Bran)
# 162  Cereal (Post Shredded Wheat'n Bran)
# 163  Cereal (Post Shredded Wheat'n Bran)
# 164  Cereal (Post Shredded Wheat'n Bran)
# 165  Cereal (Post Shredded Wheat'n Bran)
# 166  Cereal (Post Shredded Wheat'n Bran)
# 167  Cereal (Post Shredded Wheat'n Bran)
# 168  Cereal (Post Shredded Wheat'n Bran)
# 169  Cereal (Post Shredded Wheat'n Bran)
# 170  Cereal (Post Shredded Wheat'n Bran)
# 171  Cereal (Post Shredded Wheat'n Bran)
# 172  Cereal (Post Shredded Wheat'n Bran)
# 173  Cereal (Post Shredded Wheat'n Bran)
# 174  Cereal (Post Shredded Wheat'n Bran)
# 175  Cereal (Post Shredded Wheat'n Bran)
# 176  Cereal (Post Shredded Wheat'n Bran)
# 177  Cereal (Post Shredded Wheat'n Bran)
# 178  Cereal (Post Shredded Wheat'n Bran)
# 179  Cereal (Post Shredded Wheat'n Bran)
# 180  Cereal (Post Shredded Wheat'n Bran)
# 181  Cereal (Post Shredded Wheat'n Bran)
# 182  Cereal (Post Shredded Wheat'n Bran)
# 183  Cereal (Post Shredded Wheat'n Bran)
# 184  Cereal (Post Shredded Wheat'n Bran)
# 185  Cereal (Post Shredded Wheat'n Bran)
# 186  Cereal (Post Shredded Wheat)
# 187  Cereal (Post Shredded Wheat)
# 188  Cereal (Post Shredded Wheat)
# 189  Cereal (Post Shredded Wheat)
# 190  Cereal (Post Shredded Wheat)
# 191  Cereal (Post Shredded Wheat)
# 192  Cereal (Post Shredded Wheat)
# 193  Cereal (Post Shredded Wheat)
# 194  Cereal (Post Shredded Wheat)
# 195  Cereal (Post Shredded Wheat)
# 196  Cereal (Post Shredded Wheat)
# 197  Cereal (Post Shredded Wheat)
# 198  Cereal (Post Shredded Wheat)
# 199  Cereal (Post Shredded Wheat)
# 200  Cereal (Post Shredded Wheat)
# 201  Cereal (Post Shredded Wheat)
# 202  Cereal (Post Shredded Wheat)
# 203  Cereal (Post Shredded Wheat)
# 204  Cereal (Post Shredded Wheat)
# 205  Cereal (Post Shredded Wheat)
# 206  Cereal (Post Shredded Wheat)
# 207  Cereal (Post Shredded Wheat)
# 208  Cereal (Post Shredded Wheat)
# 209  Cereal (Post Shredded Wheat)
# 210  Cereal (Post Shredded Wheat)
# 211  Cereal (Post Shredded Wheat)
# 212  Cereal (Post Shredded Wheat)
# 213  Cereal (Post Shredded Wheat)
# 214  Cereal (Post Shredded Wheat)
# 215  Cereal (Post Shredded Wheat)
# 216  Cereal (Post Shredded Wheat)
# 217  Cereal (Post Shredded Wheat)
# 218  Cereal (Post Shredded Wheat)
# 219  Cereal (Post Shredded Wheat)
# 220  Cereal (Post Shredded Wheat)
# 221  Cereal (Post Shredded Wheat)
# 222  Cereal (Post Shredded Wheat)
# 223  Cereal (Post Shredded Wheat)
# 224  Cereal (Post Shredded Wheat)
# 225  Cereal (Post Shredded Wheat)
# 226  Cereal (Post Shredded Wheat)
# 227  Cereal (Post Shredded Wheat)
# 228  Cereal (Post Shredded Wheat)
# 229  Cereal (Post Shredded Wheat)
# 230  Cereal (Post Shredded Wheat)
# 231  Cereal (Post Shredded Wheat)
# 232  Cereal (Post Shredded Wheat)
# 233  Cereal (Post Shredded Wheat)
# 234  Cereal (Post Shredded Wheat)
# 235  Cereal (Post Shredded Wheat)
# 236  Cereal (Post Shredded Wheat)
# 237  Cereal (Post Shredded Wheat)
# 238  Cereal (Post Shredded Wheat)
# 239  Cereal (Post Shredded Wheat)
# 240  Cereal (Post Shredded Wheat)
# 241  Cereal (Post Shredded Wheat)
# 242  Cereal (Post Shredded Wheat)
# 243  Cereal (Post Shredded Wheat)
# 244  Cereal (Post Shredded Wheat)
# 245  Cereal (Post Shredded Wheat)
# 246  Cereal (Post Shredded Wheat)
# 247  Cereal (Post Shredded Wheat)
#
#                                nut name  nut code  nut value  \
# 0    Fatty acids, total polyunsaturated  0        -1.042358
# 1    Fatty acids, total monounsaturated  1        -1.109662
# 2    22:5 n-3                            2        -20.000000
# 3    22:1                                3        -20.000000
# 4    20:5 n-3                            4        -20.000000
# 5    20:1                                5        -20.000000
# 6    18:4                                6        -20.000000
# 7    16:1                                7        -1.734601
# 8    22:6 n-3                            8        -20.000000
# 9    20:4                                9        -20.000000
# 10   18:3                                10       -1.007120
# 11   18:2                                11       -1.040964
# 12   18:1                                12       -1.186358
# 13   18:0                                13       -0.971861
# 14   16:0                                14       -0.587427
# 15   14:0                                15       -0.559616
# 16   12:0                                16        0.000000
# 17   10:0                                17       -20.000000
# 18   8:0                                 18       -20.000000
# 19   6:0                                 19       -20.000000
# 20   4:0                                 20       -20.000000
# 21   Fatty acids, total saturated        21       -0.616774
# 22   Cholesterol                         22       -20.000000
# 23   Vitamin B-12, added                 23       -20.000000
# 24   Vitamin E, added                    24       -20.000000
# 25   Folate, food                        25       -1.425009
# 26   Folic acid                          26       -20.000000
# 27   Vitamin K (phylloquinone)           27        0.051293
# 28   Choline, total                      28       -0.846850
# 29   Vitamin B-12                        29       -20.000000
# 30   Folate, total                       30        1.474097
# 31   Vitamin B-6                         31       -0.415492
# 32   Niacin                              32       -0.454366
# 33   Riboflavin                          33       -1.570351
# 34   Thiamin                             34        0.217391
# 35   Vitamin C                           35       -20.000000
# 36   Lutein + zeaxanthin                 36       -0.368651
# 37   Lycopene                            37       -20.000000
# 38   Cryptoxanthin, beta                 38       -20.000000
# 39   Vitamin D (D2 + D3)                 39       -20.000000
# 40   Vitamin E (alpha-tocopherol)        40       -0.876812
# 41   Carotene, alpha                     41       -20.000000
# 42   Carotene, beta                      42       -1.098612
# 43   Retinol                             43       -20.000000
# 44   Selenium                            44       -2.143293
# 45   Copper                              45       -1.076808
# 46   Zinc                                46       -1.256208
# 47   Sodium                              47        5.448890
# 48   Potassium                           48       -1.083499
# 49   Phosphorus                          49       -0.774342
# 50   Magnesium                           50       -1.594815
# 51   Iron                                51        0.974185
# 52   Calcium                             52       -0.824724
# 53   Fiber, total dietary                53       -1.191589
# 54   Sugars, total                       54        3.073145
# 55   Theobromine                         55       -20.000000
# 56   Caffeine                            56       -20.000000
# 57   Water                               57       -1.038761
# 58   Alcohol                             58       -20.000000
# 59   Carbohydrate                        59        0.221313
# 60   Total Fat                           60       -0.853592
# 61   Protein                             61       -0.326363
# 62   Fatty acids, total polyunsaturated  0        -0.051960
# 63   Fatty acids, total monounsaturated  1         1.837280
# 64   22:5 n-3                            2        -20.000000
# 65   22:1                                3        -20.000000
# 66   20:5 n-3                            4        -20.000000
# 67   20:1                                5        -20.000000
# 68   18:4                                6        -20.000000
# 69   16:1                                7        -0.060625
# 70   22:6 n-3                            8        -20.000000
# 71   20:4                                9        -20.000000
# 72   18:3                                10       -0.281712
# 73   18:2                                11       -0.032398
# 74   18:1                                12        1.854883
# 75   18:0                                13        1.279431
# 76   16:0                                14        0.086112
# 77   14:0                                15       -0.847298
# 78   12:0                                16       -0.693147
# 79   10:0                                17       -20.000000
# 80   8:0                                 18       -20.000000
# 81   6:0                                 19       -20.000000
# 82   4:0                                 20       -20.000000
# 83   Fatty acids, total saturated        21        0.238892
# 84   Cholesterol                         22       -20.000000
# 85   Vitamin B-12, added                 23       -20.000000
# 86   Vitamin E, added                    24       -20.000000
# 87   Folate, food                        25       -1.425009
# 88   Folic acid                          26       -20.000000
# 89   Vitamin K (phylloquinone)           27        0.489548
# 90   Choline, total                      28       -1.246065
# 91   Vitamin B-12                        29       -20.000000
# 92   Folate, total                       30        2.068304
# 93   Vitamin B-6                         31        0.205334
# 94   Niacin                              32        0.138820
# 95   Riboflavin                          33        0.812277
# 96   Thiamin                             34        0.830495
# 97   Vitamin C                           35       -20.000000
# 98   Lutein + zeaxanthin                 36        0.965081
# 99   Lycopene                            37       -20.000000
# 100  Cryptoxanthin, beta                 38       -20.000000
# 101  Vitamin D (D2 + D3)                 39       -20.000000
# 102  Vitamin E (alpha-tocopherol)        40        0.221800
# 103  Carotene, alpha                     41       -20.000000
# 104  Carotene, beta                      42        1.969441
# 105  Retinol                             43       -20.000000
# 106  Selenium                            44       -1.866661
# 107  Copper                              45       -1.607436
# 108  Zinc                                46       -2.089117
# 109  Sodium                              47        5.339939
# 110  Potassium                           48       -1.723105
# 111  Phosphorus                          49       -1.773177
# 112  Magnesium                           50       -2.304223
# 113  Iron                                51        1.162441
# 114  Calcium                             52       -0.735111
# 115  Fiber, total dietary                53       -2.051790
# 116  Sugars, total                       54        3.887330
# 117  Theobromine                         55       -20.000000
# 118  Caffeine                            56       -20.000000
# 119  Water                               57       -1.226813
# 120  Alcohol                             58       -20.000000
# 121  Carbohydrate                        59        0.210194
# 122  Total Fat                           60        0.540955
# 123  Protein                             61       -0.702840
# 124  Fatty acids, total polyunsaturated  0        -0.595046
# 125  Fatty acids, total monounsaturated  1        -0.657677
# 126  22:5 n-3                            2        -20.000000
# 127  22:1                                3        -20.000000
# 128  20:5 n-3                            4        -20.000000
# 129  20:1                                5        -20.000000
# 130  18:4                                6        -20.000000
# 131  16:1                                7        -0.194156
# 132  22:6 n-3                            8        -20.000000
# 133  20:4                                9        -20.000000
# 134  18:3                                10       -1.129010
# 135  18:2                                11       -0.558880
# 136  18:1                                12       -0.672363
# 137  18:0                                13       -0.566395
# 138  16:0                                14       -0.316881
# 139  14:0                                15       -0.559616
# 140  12:0                                16       -20.000000
# 141  10:0                                17       -20.000000
# 142  8:0                                 18       -20.000000
# 143  6:0                                 19       -20.000000
# 144  4:0                                 20       -20.000000
# 145  Fatty acids, total saturated        21       -0.381935
# 146  Cholesterol                         22       -20.000000
# 147  Vitamin B-12, added                 23       -20.000000
# 148  Vitamin E, added                    24       -20.000000
# 149  Folate, food                        25       -0.968250
# 150  Folic acid                          26       -20.000000
# 151  Vitamin K (phylloquinone)           27        0.051293
# 152  Choline, total                      28       -1.169623
# 153  Vitamin B-12                        29       -20.000000
# 154  Folate, total                       30       -0.968250
# 155  Vitamin B-6                         31       -2.790398
# 156  Niacin                              32       -0.959792
# 157  Riboflavin                          33       -1.975816
# 158  Thiamin                             34       -0.961264
# 159  Vitamin C                           35       -20.000000
# 160  Lutein + zeaxanthin                 36       -0.016807
# 161  Lycopene                            37       -20.000000
# 162  Cryptoxanthin, beta                 38       -20.000000
# 163  Vitamin D (D2 + D3)                 39       -20.000000
# 164  Vitamin E (alpha-tocopherol)        40       -0.312598
# 165  Carotene, alpha                     41       -20.000000
# 166  Carotene, beta                      42       -20.000000
# 167  Retinol                             43       -20.000000
# 168  Selenium                            44       -2.247433
# 169  Copper                              45       -20.000000
# 170  Zinc                                46       -0.842723
# 171  Sodium                              47       -20.000000
# 172  Potassium                           48       -1.106256
# 173  Phosphorus                          49       -0.885190
# 174  Magnesium                           50       -1.256042
# 175  Iron                                51       -1.004765
# 176  Calcium                             52       -0.506270
# 177  Fiber, total dietary                53       -1.068691
# 178  Sugars, total                       54        0.603916
# 179  Theobromine                         55       -20.000000
# 180  Caffeine                            56       -20.000000
# 181  Water                               57       -1.147301
# 182  Alcohol                             58       -20.000000
# 183  Carbohydrate                        59        0.223299
# 184  Total Fat                           60       -0.724213
# 185  Protein                             61       -0.352549
# 186  Fatty acids, total polyunsaturated  0        -0.562785
# 187  Fatty acids, total monounsaturated  1        -0.769794
# 188  22:5 n-3                            2        -20.000000
# 189  22:1                                3        -20.000000
# 190  20:5 n-3                            4        -20.000000
# 191  20:1                                5        -20.000000
# 192  18:4                                6        -20.000000
# 193  16:1                                7        -0.753772
# 194  22:6 n-3                            8        -20.000000
# 195  20:4                                9        -0.916291
# 196  18:3                                10       -0.869499
# 197  18:2                                11       -0.540188
# 198  18:1                                12       -0.800484
# 199  18:0                                13       -0.666479
# 200  16:0                                14       -0.401874
# 201  14:0                                15       -1.252763
# 202  12:0                                16       -20.000000
# 203  10:0                                17       -20.000000
# 204  8:0                                 18       -20.000000
# 205  6:0                                 19       -20.000000
# 206  4:0                                 20       -20.000000
# 207  Fatty acids, total saturated        21       -0.441833
# 208  Cholesterol                         22       -20.000000
# 209  Vitamin B-12, added                 23       -20.000000
# 210  Vitamin E, added                    24       -20.000000
# 211  Folate, food                        25       -0.631778
# 212  Folic acid                          26       -20.000000
# 213  Vitamin K (phylloquinone)           27       -0.305382
# 214  Choline, total                      28       -1.169623
# 215  Vitamin B-12                        29       -20.000000
# 216  Folate, total                       30       -0.631778
# 217  Vitamin B-6                         31       -2.128999
# 218  Niacin                              32       -0.825060
# 219  Riboflavin                          33       -1.858033
# 220  Thiamin                             34       -0.607092
# 221  Vitamin C                           35       -20.000000
# 222  Lutein + zeaxanthin                 36       -1.003302
# 223  Lycopene                            37       -20.000000
# 224  Cryptoxanthin, beta                 38       -20.000000
# 225  Vitamin D (D2 + D3)                 39       -20.000000
# 226  Vitamin E (alpha-tocopherol)        40       -1.538210
# 227  Carotene, alpha                     41       -20.000000
# 228  Carotene, beta                      42       -20.000000
# 229  Retinol                             43       -20.000000
# 230  Selenium                            44       -2.869963
# 231  Copper                              45       -1.028017
# 232  Zinc                                46       -0.895194
# 233  Sodium                              47        0.000000
# 234  Potassium                           48       -1.124321
# 235  Phosphorus                          49       -0.980500
# 236  Magnesium                           50       -1.532295
# 237  Iron                                51       -1.418013
# 238  Calcium                             52       -0.247408
# 239  Fiber, total dietary                53       -1.238842
# 240  Sugars, total                       54        0.808217
# 241  Theobromine                         55       -20.000000
# 242  Caffeine                            56       -20.000000
# 243  Water                               57       -0.776397
# 244  Alcohol                             58       -20.000000
# 245  Carbohydrate                        59        0.217454
# 246  Total Fat                           60       -0.724213
# 247  Protein                             61       -0.294781
#
#                                                                                                                                     hover  \
# 0    Fatty acids, total polyunsaturated: 0.35262206148282094<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 1    Fatty acids, total monounsaturated: 0.32967032967032966<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 2    22:5 n-3: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 3    22:1: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 4    20:5 n-3: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 5    20:1: inf<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 6    18:4: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 7    16:1: 0.1764705882352941<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 8    22:6 n-3: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 9    20:4: 0.0<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 10   18:3: 0.3652694610778443<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 11   18:2: 0.3531142717018146<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 12   18:1: 0.3053311793214863<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 13   18:0: 0.3783783783783784<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 14   16:0: 0.5557553956834532<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 15   14:0: 0.5714285714285714<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 16   12:0: 1.0<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 17   10:0: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 18   8:0: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 19   6:0: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 20   4:0: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 21   Fatty acids, total saturated: 0.5396825396825398<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 22   Cholesterol: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 23   Vitamin B-12, added: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 24   Vitamin E, added: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 25   Folate, food: 0.24050632911392408<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 26   Folic acid: inf<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 27   Vitamin K (phylloquinone): 1.0526315789473684<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 28   Choline, total: 0.42876344086021506<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 29   Vitamin B-12: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 30   Folate, total: 4.367088607594937<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 31   Vitamin B-6: 0.6600153491941674<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 32   Niacin: 0.6348504934452791<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 33   Riboflavin: 0.20797227036398752<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 34   Thiamin: 1.2428298279158698<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 35   Vitamin C: inf<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 36   Lutein + zeaxanthin: 0.6916666666669549<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 37   Lycopene: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# 38   Cryptoxanthin, beta: nan<br />Cereal (Post Grape-Nuts)<br />Food code:57230000
# ...
# 176  Calcium: 0.6027397260273972<br />Cereal (Post Shredded Wheat'n Bran)<br />Food code:57341000
# 177  Fiber, total dietary: 0.34345794392523366<br />Cereal (Post Shredded Wheat'n Bran)<br />Food code:57341000
# 178  Sugars, total: 1.829268292682927<br />Cereal (Post Shredded Wheat'n Bran)<br />Food code:57341000
# 179  Theobromine: nan<br />Cereal (Post Shredded Wheat'n Bran)<br />Food code:57341000
# 180  Caffeine: nan<br />Cereal (Post Shredded Wheat'n Bran)<br />Food code:57341000
# 181  Water: 0.31749241658240646<br />Cereal (Post Shredded Wheat'n Bran)<br />Food code:57341000
# 182  Alcohol: nan<br />Cereal (Post Shredded Wheat'n Bran)<br />Food code:57341000
# 183  Carbohydrate: 1.2501937684079987<br />Cereal (Post Shredded Wheat'n Bran)<br />Food code:57341000
# 184  Total Fat: 0.4847058823529412<br />Cereal (Post Shredded Wheat'n Bran)<br />Food code:57341000
# 185  Protein: 0.7028938906752411<br />Cereal (Post Shredded Wheat'n Bran)<br />Food code:57341000
# 186  Fatty acids, total polyunsaturated: 0.5696202531645569<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 187  Fatty acids, total monounsaturated: 0.4631083202511774<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 188  22:5 n-3: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 189  22:1: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 190  20:5 n-3: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 191  20:1: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 192  18:4: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 193  16:1: 0.47058823529411764<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 194  22:6 n-3: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 195  20:4: 0.4<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 196  18:3: 0.4191616766467066<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 197  18:2: 0.582638548307994<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 198  18:1: 0.44911147011308566<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 199  18:0: 0.5135135135135135<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 200  16:0: 0.6690647482014388<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 201  14:0: 0.2857142857142857<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 202  12:0: 0.0<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 203  10:0: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 204  8:0: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 205  6:0: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 206  4:0: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 207  Fatty acids, total saturated: 0.6428571428571429<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 208  Cholesterol: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 209  Vitamin B-12, added: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 210  Vitamin E, added: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 211  Folate, food: 0.5316455696202531<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 212  Folic acid: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 213  Vitamin K (phylloquinone): 0.7368421052631579<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 214  Choline, total: 0.31048387096774194<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 215  Vitamin B-12: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 216  Folate, total: 0.5316455696202531<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 217  Vitamin B-6: 0.11895625479662318<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 218  Niacin: 0.4382088672853145<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 219  Riboflavin: 0.15597920277299063<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 220  Thiamin: 0.5449330783938814<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 221  Vitamin C: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 222  Lutein + zeaxanthin: 0.36666666666681946<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 223  Lycopene: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 224  Cryptoxanthin, beta: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 225  Vitamin D (D2 + D3): nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 226  Vitamin E (alpha-tocopherol): 0.21476510067114096<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 227  Carotene, alpha: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 228  Carotene, beta: 0.0<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 229  Retinol: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 230  Selenium: 0.056701030927835065<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 231  Copper: 0.35771543086172347<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 232  Zinc: 0.4085281980742835<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 233  Sodium: 1.0<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 234  Potassium: 0.32487309644670054<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 235  Phosphorus: 0.37512339585389937<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 236  Magnesium: 0.21603927986906712<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 237  Iron: 0.24219489120151375<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 238  Calcium: 0.7808219178082193<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 239  Fiber, total dietary: 0.28971962616822433<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 240  Sugars, total: 2.2439024390243905<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 241  Theobromine: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 242  Caffeine: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 243  Water: 0.4600606673407482<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 244  Alcohol: nan<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 245  Carbohydrate: 1.2429080762672453<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 246  Total Fat: 0.4847058823529412<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
# 247  Protein: 0.7446945337620579<br />Cereal (Post Shredded Wheat)<br />Food code:57417000
#
#      nut value grams
# 0    0.352622
# 1    0.329670
# 2   NaN
# 3   NaN
# 4   NaN
# 5    inf
# 6   NaN
# 7    0.176471
# 8   NaN
# 9    0.000000
# 10   0.365269
# 11   0.353114
# 12   0.305331
# 13   0.378378
# 14   0.555755
# 15   0.571429
# 16   1.000000
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21   0.539683
# 22  NaN
# 23  NaN
# 24  NaN
# 25   0.240506
# 26   inf
# 27   1.052632
# 28   0.428763
# 29  NaN
# 30   4.367089
# 31   0.660015
# 32   0.634850
# 33   0.207972
# 34   1.242830
# 35   inf
# 36   0.691667
# 37  NaN
# 38  NaN
# 39  NaN
# 40   0.416107
# 41  NaN
# 42   0.333333
# 43  NaN
# 44   0.117268
# 45   0.340681
# 46   0.284732
# 47   232.500000
# 48   0.338409
# 49   0.461007
# 50   0.202946
# 51   2.649007
# 52   0.438356
# 53   0.303738
# 54   21.609756
# 55  NaN
# 56  NaN
# 57   0.353893
# 58  NaN
# 59   1.247714
# 60   0.425882
# 61   0.721543
# 62   0.949367
# 63   6.279435
# 64  NaN
# 65  NaN
# 66  NaN
# 67   inf
# 68  NaN
# 69   0.941176
# 70  NaN
# 71   0.000000
# 72   0.754491
# 73   0.968122
# 74   6.390953
# 75   3.594595
# 76   1.089928
# 77   0.428571
# 78   0.500000
# 79  NaN
# 80  NaN
# 81  NaN
# 82  NaN
# 83   1.269841
# 84  NaN
# 85  NaN
# 86  NaN
# 87   0.240506
# 88   inf
# 89   1.631579
# 90   0.287634
# 91  NaN
# 92   7.911392
# 93   1.227936
# 94   1.148917
# 95   2.253033
# 96   2.294455
# 97  NaN
# 98   2.625000
# 99  NaN
# 100 NaN
# 101 NaN
# 102  1.248322
# 103 NaN
# 104  7.166667
# 105 NaN
# 106  0.154639
# 107  0.200401
# 108  0.123796
# 109  208.500000
# 110  0.178511
# 111  0.169793
# 112  0.099836
# 113  3.197729
# 114  0.479452
# 115  0.128505
# 116  48.780488
# 117 NaN
# 118 NaN
# 119  0.293225
# 120 NaN
# 121  1.233917
# 122  1.717647
# 123  0.495177
# 124  0.551537
# 125  0.518053
# 126 NaN
# 127 NaN
# 128 NaN
# 129 NaN
# 130 NaN
# 131  0.823529
# 132 NaN
# 133  0.000000
# 134  0.323353
# 135  0.571849
# 136  0.510501
# 137  0.567568
# 138  0.728417
# 139  0.571429
# 140  0.000000
# 141 NaN
# 142 NaN
# 143 NaN
# 144 NaN
# 145  0.682540
# 146 NaN
# 147 NaN
# 148 NaN
# 149  0.379747
# 150 NaN
# 151  1.052632
# 152  0.310484
# 153 NaN
# 154  0.379747
# 155  0.061397
# 156  0.382972
# 157  0.138648
# 158  0.382409
# 159 NaN
# 160  0.983333
# 161 NaN
# 162 NaN
# 163 NaN
# 164  0.731544
# 165 NaN
# 166  0.000000
# 167 NaN
# 168  0.105670
# 169  0.000000
# 170  0.430536
# 171  0.000000
# 172  0.330795
# 173  0.412636
# 174  0.284779
# 175  0.366131
# 176  0.602740
# 177  0.343458
# 178  1.829268
# 179 NaN
# 180 NaN
# 181  0.317492
# 182 NaN
# 183  1.250194
# 184  0.484706
# 185  0.702894
# 186  0.569620
# 187  0.463108
# 188 NaN
# 189 NaN
# 190 NaN
# 191 NaN
# 192 NaN
# 193  0.470588
# 194 NaN
# 195  0.400000
# 196  0.419162
# 197  0.582639
# 198  0.449111
# 199  0.513514
# 200  0.669065
# 201  0.285714
# 202  0.000000
# 203 NaN
# 204 NaN
# 205 NaN
# 206 NaN
# 207  0.642857
# 208 NaN
# 209 NaN
# 210 NaN
# 211  0.531646
# 212 NaN
# 213  0.736842
# 214  0.310484
# 215 NaN
# 216  0.531646
# 217  0.118956
# 218  0.438209
# 219  0.155979
# 220  0.544933
# 221 NaN
# 222  0.366667
# 223 NaN
# 224 NaN
# 225 NaN
# 226  0.214765
# 227 NaN
# 228  0.000000
# 229 NaN
# 230  0.056701
# 231  0.357715
# 232  0.408528
# 233  1.000000
# 234  0.324873
# 235  0.375123
# 236  0.216039
# 237  0.242195
# 238  0.780822
# 239  0.289720
# 240  2.243902
# 241 NaN
# 242 NaN
# 243  0.460061
# 244 NaN
# 245  1.242908
# 246  0.484706
# 247  0.744695

# %%
# file_save = ['Ready-to-eat cereal.html', 'Nutrition bars.html', 'wheat_ingredients_from_FNDDS_2011.html',
#             'Lasagna.html'][3]
if compare_nuts:
#     xaxis_title = 'log(cereal) - log(UnprocessedWheatBran)<br>vs.<br>log(x) for UnprocessedWheatBran'
#     xaxis_title = 'log(cereal) - log(UnprocessedWheatBran)'
    xaxis_title = r'$log(x_{cereal} / x_{WheatBran})$'
else:
    xaxis_title = r'$log(x)$'
    pass

if False:
    plot_title = None
else:
    plot_title = '{} | DataSource: {}'.format(case_study['name'].title(), data_source_name)

font_size = 16
width=[1200, 900][-1]
height=1200

if len(col_nuts) > 62:
    height = 1400
    
file_save = (case_study['name'] + '_source_' + data_source_name).replace(' ', '_') + '.html'

FPro_type = ['FPS', 'ens_FPS' ,'ens_min_FPS'][2]

layout = go.Layout(
  margin=go.layout.Margin(
        l=0, #left margin
        r=0, #right margin
        b=0, #bottom margin
        t=0 if plot_title is None else 40  #top margin
    )
)

fig = go.Figure(layout=layout)

# colors = gen_rand_colors(len(plot_df['Food code'].unique()))

if len(foods_df) == 2:
    colors = ['#e6194B', '#469990', '#ffe119', '#911eb4']
    marker_symbols = ['circle', 'circle', 'circle', 'circle']
else:
    colors = ['#911eb4', '#e6194B', '#ffe119', '#469990', 'black']
    marker_symbols = ['cross', 'star-triangle-up', 'circle', 'diamond', 'cross']
    pass

markers_opacity = 0.75
marker_size = [6, 8][1]
max_x = -20

for i, food_code in enumerate(plot_df['Food code'].unique()):
    tmp_df = plot_df[plot_df['Food code'] == food_code]
    
    if np.ceil(max(tmp_df['nut value'])) > max_x:
        max_x = np.ceil(max(tmp_df['nut value']))
        
    food_desc = tmp_df['Main food description'].unique()[0]
    
    FPro = tmp_df['FPS'].unique()[0]
#     FPro_ens_avg = tmp_df['ens_FPS'].unique()[0]
#     FPro_ens_min = tmp_df['ens_min_FPS'].unique()[0]
    FPro_ens_min = tmp_df['min_FPS'].unique()[0]
    FPro_ens_std = tmp_df['std_FPS'].unique()[0]
    
    food_desc = '<br />'.join(textwrap.wrap(food_desc, 15))

#     food_desc = '<br />'.join(textwrap.wrap(food_desc, 30))

#     food_desc = food_desc + '<br />FPro:({:.3f}, min:{:.3f}, std:{:.3f})'.format(FPro, FPro_ens_min, FPro_ens_std)
    food_desc = food_desc + '<br />FPro: {:.4f}'.format(FPro, FPro_ens_min, FPro_ens_std)
    food_desc = food_desc + '<br />'
    

    marker = dict(
        size=marker_size, symbol = 'circle', opacity=markers_opacity, #line=dict(width=1,color='DarkSlateGrey')
        color=colors[i], 
        # color='rgb({}, {}, {})'.format(colors[i][0]*255, colors[i][1]*255, colors[i][2]*255)
    )
    
    line=dict(
        width=1, dash='dash',
        color='rgb({}, {}, {})'.format(colors[i][0]*255, colors[i][1]*255, colors[i][2]*255)
        # color='rgba(255, 0, 0, 0.5)' # FOR THIS TO WORK YOU MUST HANDLE ALL COLORS YOURSELF
     )
    
    fig.add_trace(
            go.Scatter(
                x=tmp_df['nut value'],
                y=tmp_df['nut code'], 
                hovertext=tmp_df['hover'], 
#                 line=line,
                marker=marker,
                mode=['markers', 'markers+lines'][0],
                name=food_desc,
                marker_symbol=marker_symbols[i]
        ))
    pass

if compare_nuts:
    fig.add_vline(x=0, line_width=2, line_dash="dash", line_color="black")


# more on gridlines: https://codepen.io/MojtabaSamimi/pen/qBOwjoq?editors=0010
fig.update_layout(
    title = plot_title,
    width=width,
    height=height,
    yaxis = dict(
        tickmode = 'array',
        tickvals = list(range(0, len(col_nuts))),
        ticktext = col_nuts,
        zeroline=False, #adds zeroline!
        gridcolor= "rgb(231, 222, 222)"
    ),
    xaxis= dict(
        title=xaxis_title,
#       "tickcolor": "orange",
#       "tickwidth": 50,
        gridcolor= "rgb(231, 222, 222)",
        gridwidth= 1,
        zeroline=False, #adds zeroline!
#         dtick=1,
        tickvals=np.arange(-20, max_x + 1, 1)
    ),
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    font= {
        'family': 'Times New Roman',
        'size': font_size,
        'color': '#000000'
    }
)

# ‘paper_bgcolor’: ‘rgba(0, 0, 0, 0)

fig.update_xaxes(range=[-21, 6], autorange=False)
fig.update_yaxes(range=[-1, len(col_nuts)], autorange=False)
# fig.update_xaxes(autorange=False)

# fig.write_image(file_save + '.pdf', format='pdf', scale=8)
# print(file_save + '.pdf')
fig.write_image(file_save + '.png', format='png', scale=8)
print(file_save + '.png')

fig.write_html(file_save)

pio.show(fig, renderer='browser', validate=True)
# Out:
# compare_POST_four_cereals_vs_UnprocessedWheatBran_source_FNDDS2015+2011.html.png

# %%
print(plot_df['Food code'].value_counts())

# plot_df.to_csv('D:/FProXFinal/FigS10/FigS10_A.csv')
# plot_df.to_csv('D:/FProXFinal/FigS10/FigS10_B.csv')
# Out:
# 57417000    62
# 57237300    62
# 57341000    62
# 57230000    62
# Name: Food code, dtype: int64

# %%
raise Exception('DONE!')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-30-18b4ce5887bc> in <module>
# ----> 1 raise Exception('DONE!')
#
# Exception: DONE!

# %% [raw]
# fig.write_image(file_save + '.png', format='png', scale=4)
# file_save + '.png'

# %%
fig.write_html(file_save)
file_save

# %% [markdown]
# # Raw Items FPro Plot with Stadard Error!

# %%
raw_foods = (
    fndds_cons_df[
        (fndds_cons_df['Main food description'].str.contains(', raw')) & 
        (fndds_cons_df['cat_digit_1'].isin(['Fruits', 'Vegetables'])) &
        (~fndds_cons_df['Main food description'].str.contains('salad'))
    ]
    .sort_values(by='FPS', ascending=True)
    .reset_index(drop=True)
    .reset_index(drop=False)
    .rename(columns={'index': 'rank'})
)

# raw_foods

# %%
fig = go.Figure()

if False:
    for cat in raw_foods['cat_digit_1'].unique():
        raw_foods_cat_df = raw_foods[raw_foods['cat_digit_1'] == cat]

        fig.add_trace(
                go.Scatter(
                    x=raw_foods_cat_df['FPS'],
                    y=raw_foods_cat_df['rank'],
    #                 hovertext=tmp_df['hover'], 
    #                 line=line,
    #                 marker=marker,
                    mode=['markers', 'markers+lines'][0],
                    name=cat,
                    marker_symbol='circle',
    #                 error_x=raw_foods_cat_df["std_FPS"], 
    #                 error_y=raw_foods_cat_df["std_FPS"]
            )
        )

        pass


    
fig = px.scatter(
    raw_foods, x="FPS", y="rank", color="cat_digit_1",
    error_x="std_FPS", 
#     error_y="std_FPS", 
    hover_data=['Main food description']
)

# Main food description
fig.update_traces(marker_size=5, marker_symbol='circle')

fig.update_layout(
#     title = 'FPro type={} | {}'.format(FPro_type, file_save),
    width=900,
    height=1500,
    legend_title='',
    yaxis = dict(
        title='',
        tickmode = 'array',
        tickvals = list(range(0,len(raw_foods))),
        range=[-1,len(raw_foods)],
        ticktext = raw_foods['Main food description'],
        zeroline=False,
        gridcolor= "rgb(231, 222, 222)",
    ),
    xaxis= dict(
        title='FPro',
#       "tickcolor": "orange",
#       "tickwidth": 50,
        gridcolor= "rgb(231, 222, 222)",
        gridwidth= 1,
        zeroline=False,
#         dtick=1,
#         tickvals=np.arange(-20, max_x + 1, 1)
    ),
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    font= {
        'family': 'Times New Roman',
        'size': 11,
        'color': '#000000'
    }
)

# pio.show(fig, renderer='browser', validate=True)

fig.data[0].error_x.thickness = 1
fig.data[1].error_x.thickness = 1

# fig.show()
file_name = 'raw_foods_FPro_FNDDS_2015_62p.pdf'
fig.write_image(file_name, format='pdf', scale=2)
print(file_name)

# %% [raw]
# alpha = 0.8
#
# plt.figure(figsize=(6, 16), dpi=100)
#
# matplotlib.rcParams['font.serif'] = "Times New Roman"
# matplotlib.rcParams['font.family'] = "serif"
# sns.set(style="ticks", font="Times New Roman", font_scale=0.75)
# # sns.set_style({'font.family': 'serif', 'font.serif': 'Times New Roman'}, font_scale=0.5)
#
# g = sns.pointplot(
#     x='FPS', y='Main food description', hue='cat_digit_1',
#     data=raw_foods, dodge=True, join=False, #ci='std_FPS',
#     scale=0.5, plot_kws=dict(alpha=alpha), capsize=10
# )
#
# plt.setp(g.collections, alpha=alpha) #for the markers
# plt.setp(g.lines, alpha=alpha)       #for the lines
#
# ''''''

# %% [markdown]
# - https://jakevdp.github.io/PythonDataScienceHandbook/04.03-errorbars.html

# %% [markdown]
# # Compare Nuts

# %%
[c['name'] for c in case_studies]

# %%
case_study = 'POSTS Cereals vs Ingred UnprocessedWheatBran'

case_study = get_case_study(case_study)

# load_data_main()
foods_df = fndds_cons_df[fndds_cons_df['Food code'].isin(case_study['food codes'])]

col_nuts = list(foods_df.loc[:, 'Protein':'Fatty acids, total polyunsaturated'].columns)

plot_df = prep_data_for_plot(foods_df=foods_df, col_nuts=col_nuts)

print(case_study['name'], '| TYPE:', case_study['type'])
foods_df

# %%
def compare_nut_diff(ignore_on_compare_with_zero, verbos_print):
    comparison_base_df = plot_df[plot_df['Food code'] == case_study['comparison base']]

    comp_with_results = {}

    for food_code in plot_df['Food code'].unique():
        if food_code == case_study['comparison base']:
            continue       
        
        comp_with_results[food_code] = []

        comparison_with_df = plot_df[plot_df['Food code'] == food_code]
        
        
        print('-------------comparing with: {} ({})-------------'.format(
            comparison_with_df['Main food description'].values[0],
            comparison_with_df['Food code'].values[0],
        ))

        for nut_code in plot_df['nut code'].unique():
            base_val = comparison_base_df[comparison_base_df['nut code'] == nut_code]['nut value grams'].values[0]

            comp_with_val = comparison_with_df[comparison_with_df['nut code'] == nut_code]['nut value grams'].values[0]

            nut_name = comparison_base_df[comparison_base_df['nut code'] == nut_code]['nut name'].values[0]

            if base_val == comp_with_val == 0:
                perc_diff = 0
            elif base_val == 0 and comp_with_val != 0:
                perc_diff = 1
                print(f'!!Base 0 but comp NotZero ({nut_name})', '| ignore:', ignore_on_compare_with_zero)

                if ignore_on_compare_with_zero:
                    continue
            elif base_val != 0 and comp_with_val == 0:
                perc_diff = 1
                print(f'~~Base NotZero but comp 0 ({nut_name})', '| ignore:', ignore_on_compare_with_zero)

                if ignore_on_compare_with_zero:
                    continue
            else:
                perc_diff = np.abs((base_val - comp_with_val) / base_val)

            comp_with_results[food_code].append(perc_diff)

            if verbos_print:
                print(
                    'nut_code:', nut_code, 
                    '| base val:', base_val,
                    '| comp with val:', comp_with_val,
                    '| perc_diff:', perc_diff
                )
            pass
        
        comp_with_results[food_code] = np.mean(comp_with_results[food_code])

        print('@@ ABS Diff:', comp_with_results[food_code])
        pass
    
    return comp_with_results
# comparison_base_df

print('Case Study:', case_study)
comp_res = compare_nut_diff(ignore_on_compare_with_zero = True, verbos_print = False)

# print(comp_res)

comp_res_df = pd.merge(
    foods_df[['Food code', 'FPS', 'Main food description']],
    pd.DataFrame([(k, v) for k,v in comp_res.items()], columns=['Food code', 'Comp Res']),
    on='Food code', how='left'
).sort_values(by='FPS')

comp_res_df

# %% [markdown]
# # Estimation Food Source Restournt vs ETC

# %%
food_source_df = pd.read_csv('D:/Dropbox (CCNR)/Foodome Team Folder/Ravandi, Babak FDB/FoodomeDev/NHANES_2003_2018_FoodSource_Consumed.csv')

food_source_df = food_source_df[
    (food_source_df['Dietary recall status'] == 1) & 
    (food_source_df['year'].isin([2003, 2005]))
].reset_index(drop=True)

# Water removal did not make so much change!
# water_food_codes = [94000000, 94000100, 94100100, 94300100]
# food_source_df = food_source_df[~food_source_df['Food code'].isin(water_food_codes)]

len(food_source_df)
# Just plot percentage of grams consumed in every category within 2013-2016

# %%
sum_grams_consumed = food_source_df['Grams consumed'].sum()

food_grams_perc_df = (
    food_source_df.groupby('Food source')
    .agg({'Grams consumed': np.sum})
    / sum_grams_consumed
)

food_grams_perc_df = (
    food_grams_perc_df
    .sort_values(by='Grams consumed', ascending=False) * 100
).reset_index().rename(columns={'Grams consumed': '% of Grams Consumed'})

food_grams_perc_df

# %%
fig = plt.figure(figsize=(15, 15), dpi=150)

sns.set(style="ticks", font="Times New Roman", font_scale=2)

ax = sns.barplot(
    data=food_grams_perc_df, 
    x='% of Grams Consumed', 
    y='Food source', 
#     hue='status',
#     order=list(gdb_status_count_order_df[column_cat].values)
)

# %% [markdown]
# # Manul NOVA with Uncertain FPro

# %% [raw]
# training_data = pd.read_csv('D:/Dropbox (CCNR)/Foodome Team Folder/Menichetti, Giulia/FoodProcessing/Datasets/FoodProX Core Data/Training Data/RFFNDDS_2009_10_recom_Giulia_Raws_salt_99_nuts.csv')

# %%
nova_df = pd.read_excel('FNDDS_food_ingreds_2015_NOVA.xls')
fndds_FPro_df = pd.read_csv('FNDDS201520165foldsSMOTE_62Panel.csv')

nova_df = nova_df.drop_duplicates('dr12ifdcd')

ingreds_df = pd.read_excel('FNDDS_food_ingreds_2015_NOVA.xls')
ingreds_df = ingreds_df[['dr12ifdcd', 'FNDDS_food_description', 'Ingredientcode',
       'FNDDS_ingred_food_description', 'SR_code_t', 'SR_description_t',
       'Recursionlevel', 'frac', 'weight']].rename(columns={'dr12ifdcd': 'Food code'})

# %%
nova_fpro_df = pd.merge(
    fndds_FPro_df[['Food code', 'FPS', 'cat_digit_1', 'cat_digit_2', 'cat_digit_3', 'WWEIACategorydescription']],
    nova_df.rename(columns={'dr12ifdcd': 'Food code', 'FC_nova_group': 'nova_class'})[['Food code', 'FNDDS_food_description', 'nova_class']],
    on='Food code'
).sort_values('FPS')

nova_fpro_df['nova_class'].value_counts()

# %%
# nova_fpro_df[(nova_fpro_df['nova_class'] == 4) & (nova_fpro_df['FPS'] < 0.7)]
(
    nova_fpro_df[
        (nova_fpro_df['nova_class'] == 4) & (nova_fpro_df['FPS'] < 0.7)
#         & (nova_fpro_df['WWEIACategorydescription'].isin(['Chicken, whole pieces']))
    ]
    .sort_values(by='FPS', ascending=True)
#     ['WWEIACategorydescription'].value_counts()
#     .sum()
)

# %%
nova_uncertain = pd.merge(
    nova_fpro_df[(nova_fpro_df['nova_class'] == 4) & (nova_fpro_df['FPS'] < 0.7)].drop(columns='FNDDS_food_description'),
    ingreds_df, on='Food code'
)
nova_uncertain

# %% [markdown]
# # EWAS Category Color Plot

# %%
df_summary = pd.read_csv('D:/Dropbox (CCNR)/Foodome Team Folder/Menichetti, Giulia/FoodProcessing/Datasets/00 Final Package/df_summary.csv')

colors_dict_str = df_summary.drop_duplicates('category').set_index('category').sort_index()['color'].to_dict()

colors = {color: eval(rgba_str) for color, rgba_str in colors_dict_str.items()}

# %%
[(tuple(mcolors.rgb_to_hsv(mcolors.to_rgba(color)[:3])), name)
                    for name, color in colors.items()]

# %%
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors


if False:
    # colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)

    # Sort colors by hue, saturation, value and name.
    by_hsv = sorted(
        (tuple(mcolors.rgb_to_hsv(mcolors.to_rgba(color)[:3])), name)
                    for name, color in colors.items()
    )
else:
    by_hsv = [(tuple(mcolors.rgb_to_hsv(mcolors.to_rgba(color)[:3])), name)
                    for name, color in colors.items()]
    pass

sorted_names = [name for hsv, name in by_hsv]
    
n = len(sorted_names)
ncols = 1
nrows = n // ncols
if nrows == 0:
    nrows = 1

fig, ax = plt.subplots(figsize=(12, 10))

# Get height and width
X, Y = fig.get_dpi() * fig.get_size_inches()
h = Y / (nrows + 1)
w = X / ncols

for i, name in enumerate(sorted_names):
    row = i % nrows
    col = i // nrows
    y = Y - (row * h) - h

    xi_line = w * (col + 0.05)
    xf_line = w * (col + 0.25)
    xi_text = w * (col + 0.3)

    ax.text(xi_text, y, name, fontsize=(h * 0.8),
            horizontalalignment='left',
            verticalalignment='center')

    ax.hlines(y + h * 0.1, xi_line, xf_line,
              color=colors[name], linewidth=(h * 0.8))

ax.set_xlim(0, X)
ax.set_ylim(0, Y)
ax.set_axis_off()

fig.subplots_adjust(left=0, right=1,
                    top=1, bottom=0,
                    hspace=0, wspace=0)
plt.show()

# %% [markdown]
# # Challenges
#
# - https://plotly.com/python/tick-formatting/
# - https://plotly.com/python/marker-style/
# - https://plotly.com/python/line-charts/
# - line opacity colors https://stackoverflow.com/questions/50488894/plotly-py-change-line-opacity-leave-markers-opaque
# - https://stackoverflow.com/questions/470690/how-to-automatically-generate-n-distinct-colors
# - https://stackoverflow.com/questions/22408237/named-colors-in-matplotlib
